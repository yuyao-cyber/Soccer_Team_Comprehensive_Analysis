# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## Import all Datasets

# %%
#read excel
df1 = pd.DataFrame()
#concatenate sheets to one dataframe
for i in range(0,29):
    df = pd.read_excel('MW1.xlsx',sheet_name=i)
    df = pd.concat([df1,df],ignore_index=True,sort=False)
    df1 = df
df1
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 0           2122262        -1            -1        194       -954          0.0
# 1           2122263        -1            -1        186       -954          0.0
# 2           2122264        -1            -1        177       -953          0.0
# 3           2122265        -1            -1        167       -952          0.0
# 4           2122266        -1            -1        158       -952          0.0
# ...             ...       ...           ...        ...        ...          ...
# 6030284     2330198        -1            -1       -588      -3283          0.0
# 6030285     2330199        -1            -1       -588      -3280          0.0
# 6030286     2330200        -1            -1       -589      -3275          0.0
# 6030287     2330201        -1            -1       -590      -3271          0.0
# 6030288     2330202        -1            -1       -591      -3267          0.0
#
# [6030289 rows x 6 columns]

# %%
#read excel
df2 = pd.DataFrame()
#concatenate sheets to one dataframe
for i in range(0,29):
    df = pd.read_excel('MW2.xlsx',sheet_name=i)
    df = pd.concat([df2,df],ignore_index=True,sort=False)
    df2 = df
df2
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 0           2123485        -1            -1         21      -1041          0.0
# 1           2123486        -1            -1         30      -1036          0.0
# 2           2123487        -1            -1         39      -1030          0.0
# 3           2123488        -1            -1         48      -1025          0.0
# 4           2123489        -1            -1         57      -1020          0.0
# ...             ...       ...           ...        ...        ...          ...
# 5873510     2326015        -1            -1        178      -3183          0.0
# 5873511     2326016        -1            -1        174      -3184          0.0
# 5873512     2326017        -1            -1        170      -3186          0.0
# 5873513     2326018        -1            -1        165      -3186          0.0
# 5873514     2326019        -1            -1        162      -3187          0.0
#
# [5873515 rows x 6 columns]

# %%
#read excel
df5 = pd.DataFrame()
#concatenate sheets to one dataframe
for i in range(0,29):
    df = pd.read_excel('MW5.xlsx',sheet_name=i)
    df = pd.concat([df5,df],ignore_index=True,sort=False)
    df5 = df
df5
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 0           2120567        -1            -1       -428       1505          0.0
# 1           2120568        -1            -1       -426       1504          0.0
# 2           2120569        -1            -1       -425       1503          0.0
# 3           2120570        -1            -1       -423       1502          0.0
# 4           2120571        -1            -1       -421       1501          0.0
# ...             ...       ...           ...        ...        ...          ...
# 5843147     2322050         4            -1       5800       4450          0.0
# 5843148     2322051         4            -1       5800       4450          0.0
# 5843149     2322052         4            -1       5800       4450          0.0
# 5843150     2322053         4            -1       5800       4450          0.0
# 5843151     2322054         4            -1       5800       4450          0.0
#
# [5843152 rows x 6 columns]

# %%
#read excel
df7 = pd.DataFrame()
#concatenate sheets to one dataframe
for i in range(0,29):
    df = pd.read_excel('MW7.xlsx',sheet_name=i)
    df = pd.concat([df7,df],ignore_index=True,sort=False)
    df7 = df
df7
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 0           2121944         0            11         82        808         2.45
# 1           2121945         0            11         93        810         2.69
# 2           2121946         0            11        104        811         2.94
# 3           2121947         0            11        115        814         3.13
# 4           2121948         0            11        128        816         3.29
# ...             ...       ...           ...        ...        ...          ...
# 5878295     2324639         1            19        663        693         0.79
# 5878296     2324640         1            19        662        690         0.83
# 5878297     2324641         1            19        661        686         0.90
# 5878298     2324642         1            19        659        684         0.91
# 5878299     2324643         1            19        657        681         0.91
#
# [5878300 rows x 6 columns]

# %%
#read excel
df8 = pd.DataFrame()
#concatenate sheets to one dataframe
for i in range(0,29):
    df = pd.read_excel('MW8.xlsx',sheet_name=i)
    df = pd.concat([df8,df],ignore_index=True,sort=False)
    df8 = df
df8
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 0           2355083        -1            -1      -1039        299          0.0
# 1           2355084        -1            -1      -1042        301          0.0
# 2           2355085        -1            -1      -1045        302          0.0
# 3           2355086        -1            -1      -1048        304          0.0
# 4           2355087        -1            -1      -1050        305          0.0
# ...             ...       ...           ...        ...        ...          ...
# 5815713     2555622        -1            -1        856      -3246          0.0
# 5815714     2555623        -1            -1        855      -3243          0.0
# 5815715     2555624        -1            -1        855      -3238          0.0
# 5815716     2555625        -1            -1        855      -3235          0.0
# 5815717     2555626        -1            -1        854      -3232          0.0
#
# [5815718 rows x 6 columns]

# %% [markdown]
# ## MW1

# %%
#classify and group by team
df_team1 = df1.groupby('TeamType')
#list each different team
for name, team in df_team1:
    print(f"Team {name}:")
    print(team)
# Out:
# Team -1:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 0           2122262        -1            -1        194       -954          0.0
# 1           2122263        -1            -1        186       -954          0.0
# 2           2122264        -1            -1        177       -953          0.0
# 3           2122265        -1            -1        167       -952          0.0
# 4           2122266        -1            -1        158       -952          0.0
# ...             ...       ...           ...        ...        ...          ...
# 6030284     2330198        -1            -1       -588      -3283          0.0
# 6030285     2330199        -1            -1       -588      -3280          0.0
# 6030286     2330200        -1            -1       -589      -3275          0.0
# 6030287     2330201        -1            -1       -590      -3271          0.0
# 6030288     2330202        -1            -1       -591      -3267          0.0
#
# [709967 rows x 6 columns]
# Team 0:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 1321        2123583         0            10       -383      -2822         0.00
# 1322        2123584         0            10       -383      -2820         0.00
# 1323        2123585         0            10       -382      -2820         0.00
# 1324        2123586         0            10       -381      -2819         0.00
# 1325        2123587         0            10       -381      -2817         0.00
# ...             ...       ...           ...        ...        ...          ...
# 6015302     2315216         0            10       -402      -3634         0.73
# 6015303     2315217         0            10       -402      -3636         0.73
# 6015304     2315218         0            10       -402      -3638         0.76
# 6015305     2315219         0            10       -403      -3640         0.73
# 6015306     2315220         0            10       -403      -3643         0.76
#
# [1967742 rows x 6 columns]
# Team 1:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 47376       2169638         1            10       1764      -1066         2.82
# 47377       2169639         1            10       1771      -1070         2.79
# 47378       2169640         1            10       1779      -1074         2.75
# 47379       2169641         1            10       1788      -1079         2.80
# 47380       2169642         1            10       1796      -1084         2.78
# ...             ...       ...           ...        ...        ...          ...
# 6000109     2300023         1             1       3100        480         1.49
# 6000110     2300024         1             1       3095        478         1.47
# 6000111     2300025         1             1       3091        474         1.47
# 6000112     2300026         1             1       3086        471         1.47
# 6000113     2300027         1             1       3082        468         1.49
#
# [1964303 rows x 6 columns]
# Team 3:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 236290      2150611         3             0      -4884       -261         2.65
# 236291      2150612         3             0      -4885       -262         2.65
# 236292      2150613         3             0      -4887       -263         2.65
# 236293      2150614         3             0      -4886       -263         2.65
# 236294      2150615         3             0      -4884       -264         2.65
# ...             ...       ...           ...        ...        ...          ...
# 5744780     2252635         3             0      -2550         27         2.00
# 5744781     2252636         3             0      -2544         30         2.00
# 5744782     2252637         3             0      -2536         34         2.00
# 5744783     2252638         3             0      -2529         37         2.05
# 5744784     2252639         3             0      -2522         41         2.07
#
# [527703 rows x 6 columns]
# Team 4:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 92251       2214513         4            -1       5525       4425          0.0
# 92252       2214514         4            -1       5525       4425          0.0
# 92253       2214515         4            -1       5525       4425          0.0
# 92254       2214516         4            -1       5525       4425          0.0
# 92255       2214517         4            -1       5525       4425          0.0
# ...             ...       ...           ...        ...        ...          ...
# 6030211     2330125         4            -1       5525       4425          0.0
# 6030212     2330126         4            -1       5525       4425          0.0
# 6030213     2330127         4            -1       5525       4425          0.0
# 6030214     2330128         4            -1       5525       4425          0.0
# 6030215     2330129         4            -1       5525       4425          0.0
#
# [860574 rows x 6 columns]

# %%
#fetch target team 0 and 1 from groupby object to dataframe object 
team_0 = df_team1.get_group(0)
team_1 = df_team1.get_group(1)
team_0.head(2)
# Out:
#       FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 1321     2123583         0            10       -383      -2822          0.0
# 1322     2123584         0            10       -383      -2820          0.0

# %%
team_1['FrameCount'].sort_values()
# Out:
# 3119115    2122262
# 623823     2122262
# 4158820    2122262
# 2495292    2122262
# 623824     2122263
#             ...
# 4990583    2330202
# 3950878    2330202
# 5822347    2330202
# 4158819    2330202
# 1871468    2330202
# Name: FrameCount, Length: 1964303, dtype: int64

# %%
team_1_6 = team_1.loc[team_1['JerseyNumber']==6].sort_values(by='FrameCount')

# %%
team_1_6['Sprint_Count_Group'] = (team_1_6['FrameCount'].diff()>1).cumsum()
team_1_6
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  \
# 3327928     2123134         1             6       1207       1534
# 3327929     2123135         1             6       1208       1520
# 3327930     2123136         1             6       1209       1506
# 3327931     2123137         1             6       1210       1493
# 3327932     2123138         1             6       1211       1480
# ...             ...       ...           ...        ...        ...
# 1455582     2330198         1             6       1583        331
# 1455583     2330199         1             6       1581        326
# 1455584     2330200         1             6       1580        320
# 1455585     2330201         1             6       1578        316
# 1455586     2330202         1             6       1577        311
#
#          PlayerSpeed  Sprint_Count_Group
# 3327928         0.00                   0
# 3327929         0.00                   0
# 3327930         0.00                   0
# 3327931         0.00                   0
# 3327932         0.00                   0
# ...              ...                 ...
# 1455582         1.65                   3
# 1455583         1.65                   3
# 1455584         1.64                   3
# 1455585         1.64                   3
# 1455586         1.63                   3
#
# [180093 rows x 7 columns]

# %%
team_1_6.loc[team_1_6['Sprint_Count_Group'] == 0]
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  \
# 3327928     2123134         1             6       1207       1534
# 3327929     2123135         1             6       1208       1520
# 3327930     2123136         1             6       1209       1506
# 3327931     2123137         1             6       1210       1493
# 3327932     2123138         1             6       1211       1480
# ...             ...       ...           ...        ...        ...
# 3342218     2137424         1             6        394      -3380
# 3342219     2137425         1             6        394      -3380
# 3342220     2137426         1             6        394      -3380
# 3342221     2137427         1             6        394      -3379
# 3342222     2137428         1             6        394      -3378
#
#          PlayerSpeed  Sprint_Count_Group
# 3327928         0.00                   0
# 3327929         0.00                   0
# 3327930         0.00                   0
# 3327931         0.00                   0
# 3327932         0.00                   0
# ...              ...                 ...
# 3342218         0.10                   0
# 3342219         0.10                   0
# 3342220         0.10                   0
# 3342221         0.12                   0
# 3342222         0.15                   0
#
# [14295 rows x 7 columns]

# %%
team_1_6.loc[team_1_6['Sprint_Count_Group'] == 1]
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  \
# 3342258     2137464         1             6        383      -3380
# 3342259     2137465         1             6        382      -3380
# 3342260     2137466         1             6        382      -3381
# 3342261     2137467         1             6        381      -3381
# 3342262     2137468         1             6        381      -3382
# ...             ...       ...           ...        ...        ...
# 5290781     2214518         1             6       1140      -3740
# 5290782     2214519         1             6       1138      -3744
# 5290783     2214520         1             6       1136      -3747
# 5290784     2214521         1             6       1134      -3751
# 5290785     2214522         1             6       1132      -3756
#
#          PlayerSpeed  Sprint_Count_Group
# 3342258         0.00                   1
# 3342259         0.00                   1
# 3342260         0.00                   1
# 3342261         0.00                   1
# 3342262         0.00                   1
# ...              ...                 ...
# 5290781         1.36                   1
# 5290782         1.33                   1
# 5290783         1.33                   1
# 5290784         1.29                   1
# 5290785         1.29                   1
#
# [77059 rows x 7 columns]

# %%
team_1_6.loc[team_1_6['Sprint_Count_Group'] == 2]
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  \
# 326391      2240712         1             6       2654       2273
# 326392      2240713         1             6       2659       2273
# 326393      2240714         1             6       2664       2273
# 326394      2240715         1             6       2669       2273
# 326395      2240716         1             6       2674       2273
# ...             ...       ...           ...        ...        ...
# 1413231     2287847         1             6      -3444       2076
# 1413232     2287848         1             6      -3440       2073
# 1413233     2287849         1             6      -3437       2070
# 1413234     2287850         1             6      -3432       2066
# 1413235     2287851         1             6      -3428       2064
#
#          PlayerSpeed  Sprint_Count_Group
# 326391          0.00                   2
# 326392          0.00                   2
# 326393          0.00                   2
# 326394          0.00                   2
# 326395          0.00                   2
# ...              ...                 ...
# 1413231         1.27                   2
# 1413232         1.27                   2
# 1413233         1.25                   2
# 1413234         1.25                   2
# 1413235         1.27                   2
#
# [47140 rows x 7 columns]

# %%
team_1_6.loc[team_1_6['Sprint_Count_Group'] == 3]
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  \
# 1413988     2288604         1             6       -414        496
# 1413989     2288605         1             6       -410        494
# 1413990     2288606         1             6       -406        492
# 1413991     2288607         1             6       -402        489
# 1413992     2288608         1             6       -398        487
# ...             ...       ...           ...        ...        ...
# 1455582     2330198         1             6       1583        331
# 1455583     2330199         1             6       1581        326
# 1455584     2330200         1             6       1580        320
# 1455585     2330201         1             6       1578        316
# 1455586     2330202         1             6       1577        311
#
#          PlayerSpeed  Sprint_Count_Group
# 1413988         0.00                   3
# 1413989         0.00                   3
# 1413990         0.00                   3
# 1413991         0.00                   3
# 1413992         0.00                   3
# ...              ...                 ...
# 1455582         1.65                   3
# 1455583         1.65                   3
# 1455584         1.64                   3
# 1455585         1.64                   3
# 1455586         1.63                   3
#
# [41599 rows x 7 columns]

# %%
team_1['Sprint_Count_Group'] = (team_1.loc[team_1['JerseyNumber']==6].sort_values(by='FrameCount').diff()>1).cumsum()
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 3327928           0         0             0          0          0            0
# 3327929           0         0             0          0          0            0
# 3327930           0         0             0          0          0            0
# 3327931           0         0             0          0          0            0
# 3327932           0         0             0          0          0            0
# ...             ...       ...           ...        ...        ...          ...
# 1455582           3         0             0      63829      61035            5
# 1455583           3         0             0      63829      61035            5
# 1455584           3         0             0      63829      61035            5
# 1455585           3         0             0      63829      61035            5
# 1455586           3         0             0      63829      61035            5
#
# [180093 rows x 6 columns]

# %%
team_1_9 = team_1.loc[team_1['JerseyNumber']==9].sort_values(by='FrameCount')
team_1_9['Sprint_Count_Group'] = (team_1_9['FrameCount'].diff()>1).cumsum()
team_1_9
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  \
# 623823      2122262         1             9         -3       1058
# 623824      2122263         1             9        -10       1055
# 623825      2122264         1             9        -18       1050
# 623826      2122265         1             9        -24       1044
# 623827      2122266         1             9        -32       1040
# ...             ...       ...           ...        ...        ...
# 1231647     2314204         1             9          6      -2928
# 1231648     2314205         1             9          7      -2922
# 1231649     2314206         1             9          8      -2917
# 1231650     2314207         1             9          9      -2913
# 1231651     2314208         1             9         10      -2908
#
#          PlayerSpeed  Sprint_Count_Group
# 623823          0.67                   0
# 623824          0.83                   0
# 623825          1.01                   0
# 623826          1.19                   0
# 623827          1.40                   0
# ...              ...                 ...
# 1231647         1.37                   6
# 1231648         1.37                   6
# 1231649         1.41                   6
# 1231650         1.41                   6
# 1231651         1.43                   6
#
# [160962 rows x 7 columns]

# %%
team_1_18 = team_1.loc[team_1['JerseyNumber']==18].sort_values(by='FrameCount')
team_1_18['Sprint_Count_Group'] = (team_1_18['FrameCount'].diff()>1).cumsum()
team_1_18
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  \
# 2495936     2122906         1            18        539       1786
# 2495937     2122907         1            18        539       1786
# 2495938     2122908         1            18        539       1787
# 2495939     2122909         1            18        538       1787
# 2495940     2122910         1            18        538       1788
# ...             ...       ...           ...        ...        ...
# 2510725     2137695         1            18      -1360       -649
# 2510726     2137696         1            18      -1361       -643
# 2510727     2137697         1            18      -1361       -639
# 2510728     2137698         1            18      -1362       -634
# 2510729     2137699         1            18      -1364       -629
#
#          PlayerSpeed  Sprint_Count_Group
# 2495936         0.00                   0
# 2495937         0.00                   0
# 2495938         0.00                   0
# 2495939         0.00                   0
# 2495940         0.00                   0
# ...              ...                 ...
# 2510725         1.29                   0
# 2510726         1.31                   0
# 2510727         1.33                   0
# 2510728         1.34                   0
# 2510729         1.38                   0
#
# [14794 rows x 7 columns]

# %% [markdown]
# ### MW1 Team 0

# %%
import warnings
warnings.filterwarnings("ignore")

#calculate each framecount in minutes
team_0['Minutes_Played'] = 1/30/60

#Assume the instant speed is constant. Calculate the distance in each frame.
team_0['Total_Distance'] = team_0['PlayerSpeed']/30

#As a reference, according to the article 
#https://www.frontiersin.org/articles/10.3389/fspor.2023.1116293/full#:~:text=During%20official%20matches%2C%20high%2Dspeed,in%20professional%20male%20soccer%20players.
#high-speed distance ranges from 19.8km/h ~ 25.1km/h which is 5.5m/s ~ 7.0m/s
#and sprint distance ranges over 25.1km/h which is greater than 7.0m/s.

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_0['High_Speed_Distance'] = team_0.loc[(team_0['PlayerSpeed']>5.5) & (team_0['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_0['High_Speed_Distance'].fillna(0,inplace=True)

#Use distance = speed * time. Find PlayerSpeed greater than 7, then divide it by 30 to get distance
#per FrameCount
team_0['Sprint_Distance'] = team_0.loc[team_0['PlayerSpeed']>=7,'PlayerSpeed']/30
#Fill the None value in 'Sprint_Distance' with 0.
team_0['Sprint_Distance'].fillna(0,inplace=True)
team_0
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  \
# 1321        2123583         0            10       -383      -2822
# 1322        2123584         0            10       -383      -2820
# 1323        2123585         0            10       -382      -2820
# 1324        2123586         0            10       -381      -2819
# 1325        2123587         0            10       -381      -2817
# ...             ...       ...           ...        ...        ...
# 6015302     2315216         0            10       -402      -3634
# 6015303     2315217         0            10       -402      -3636
# 6015304     2315218         0            10       -402      -3638
# 6015305     2315219         0            10       -403      -3640
# 6015306     2315220         0            10       -403      -3643
#
#          PlayerSpeed  Minutes_Played  Total_Distance  High_Speed_Distance  \
# 1321            0.00        0.000556        0.000000                  0.0
# 1322            0.00        0.000556        0.000000                  0.0
# 1323            0.00        0.000556        0.000000                  0.0
# 1324            0.00        0.000556        0.000000                  0.0
# 1325            0.00        0.000556        0.000000                  0.0
# ...              ...             ...             ...                  ...
# 6015302         0.73        0.000556        0.024333                  0.0
# 6015303         0.73        0.000556        0.024333                  0.0
# 6015304         0.76        0.000556        0.025333                  0.0
# 6015305         0.73        0.000556        0.024333                  0.0
# 6015306         0.76        0.000556        0.025333                  0.0
#
#          Sprint_Distance
# 1321                 0.0
# 1322                 0.0
# 1323                 0.0
# 1324                 0.0
# 1325                 0.0
# ...                  ...
# 6015302              0.0
# 6015303              0.0
# 6015304              0.0
# 6015305              0.0
# 6015306              0.0
#
# [1967742 rows x 10 columns]

# %%
#The logic to find Sprint_Count is to divide FrameCount into groups with consecutive numbers. For each group,
#if there appears PlayerSpeed grater than 7, Sprint_Count += 1. 

# initializing list
tuple_list = []
#Set groups to divide FrameCount. If FrameCount.diff is greater than 1, set to another group.
team_0['Sprint_Count_Group'] = (team_0['FrameCount'].diff()>1).cumsum()
sprint_count_group = team_0.groupby(['Sprint_Count_Group','JerseyNumber'])
for name, group in sprint_count_group:
    #Search if any PlayerSpeed is greater than 7
    if (group['PlayerSpeed'] >=7).any():
        tuple_list.append(name)

result = defaultdict(list)
for sub in tuple_list:
    # getting all keys to values

    result[sub[1]].append(sub[0])
#put result into dict object
result = dict(result)
res_dict = dict()
for key in result:
    # getting unique key counts for each value
    res_dict[key] = len(list(set(result[key])))

res_df = pd.DataFrame(list(res_dict.items()),columns=['JerseyNumber','Sprint_Count'])

#Select columns from team_0
team0_result = team_0.groupby('JerseyNumber')[['Minutes_Played','Total_Distance','High_Speed_Distance','Sprint_Distance']].sum()
#Reset Indices to merge
team0_new = team0_result.reset_index()
#Merge two df
team0_final = team0_new.merge(res_df,how='left')
#fill Sprint_count = None with 0
team0_final = team0_final.fillna(0)
team0_final
# Out:
#     JerseyNumber  Minutes_Played  Total_Distance  High_Speed_Distance  \
# 0              1      100.165000     6240.750000            78.724667
# 1              2       99.045556    11688.446667           702.792000
# 2              6       83.178333    10105.965000           522.319333
# 3              7       64.174444     8267.044667           638.086333
# 4              8       83.215556     9988.368000           883.843000
# 5              9       91.059444     9424.042667           555.591000
# 6             10       99.078333    11913.768000           857.956000
# 7             11       36.067778     4497.446667           321.653000
# 8             12       14.531111     1930.603000           237.603333
# 9             14      101.300000    11184.940333           585.826667
# 10            15        7.852778     1034.898333             8.197667
# 11            19       13.765000     1217.887000           115.765667
# 12            21       63.907222     7946.905000           708.282333
# 13            22      100.111111    10827.206333           517.747000
# 14            26      100.077222    10240.436000           514.122333
# 15            28       35.661111     4349.858000           241.006000
#
#     Sprint_Distance  Sprint_Count
# 0          0.000000           0.0
# 1        219.651333           8.0
# 2         21.488667           6.0
# 3        100.775667           4.0
# 4        172.417667           8.0
# 5        197.345667          11.0
# 6        106.218667           8.0
# 7        160.052333           7.0
# 8         82.077333           2.0
# 9        355.854000          10.0
# 10        15.200667           1.0
# 11        59.736000           2.0
# 12       431.724333           6.0
# 13       226.902333          10.0
# 14       108.597333           8.0
# 15        69.603667           2.0

# %% [markdown]
# ### MW1 Team 1

# %%
#calculate each framecount in minutes
team_1['Minutes_Played'] = 1/30/60

#Assume the instant speed is constant. Calculate the distance in each frame.
team_1['Total_Distance'] = team_1['PlayerSpeed']/30
#As a reference, according to the article 
#https://www.frontiersin.org/articles/10.3389/fspor.2023.1116293/full#:~:text=During%20official%20matches%2C%20high%2Dspeed,in%20professional%20male%20soccer%20players.
#high-speed distance ranges from 19.8km/h ~ 25.1km/h which is 5.5m/s ~ 7.0m/s
#and sprint distance ranges over 25.1km/h which is greater than 7.0m/s.

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_1['High_Speed_Distance'] = team_1.loc[(team_1['PlayerSpeed']>5.5) & (team_1['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_1['High_Speed_Distance'].fillna(0,inplace=True)

#Use distance = speed * time. Find PlayerSpeed greater than 7, then divide it by 30 to get distance
#per FrameCount
team_1['Sprint_Distance'] = team_1.loc[team_1['PlayerSpeed']>=7,'PlayerSpeed']/30
#Fill the None value in 'Sprint_Distance' with 0.
team_1['Sprint_Distance'].fillna(0,inplace=True)

#The logic to find Sprint_Count is to divide FrameCount into groups with consecutive numbers. For each group,
# initializing list
tuple_list = []
team_1['Sprint_Count_Group'] = (team_1['FrameCount'].diff()>1).cumsum()
sprint_count_group = team_1.groupby(['Sprint_Count_Group','JerseyNumber'])
for name, group in sprint_count_group:
    #if there appears PlayerSpeed grater than 7, Sprint_Count += 1. 
    if (group['PlayerSpeed'] >=7).any():
        tuple_list.append(name)

result = defaultdict(list)
for sub in tuple_list:
    # getting all keys to values

    result[sub[1]].append(sub[0])
    
#put result into a dict object
result = dict(result)
res_dict = dict()
for key in result:
    # getting unique key counts for each value
    res_dict[key] = len(list(set(result[key])))
    
#make dataframe res_df
res_df = pd.DataFrame(list(res_dict.items()),columns=['JerseyNumber','Sprint_Count'])
#Select columns from team_1
team1_result = team_1.groupby('JerseyNumber')[['Minutes_Played','Total_Distance','High_Speed_Distance','Sprint_Distance']].sum()
#Reset Indices to merge
team1_new = team1_result.reset_index()
#Merge two df
team1_final = team1_new.merge(res_df,how='left')
#fill Sprint_count = None with 0
team1_final = team1_final.fillna(0)
team1_final
# Out:
#     JerseyNumber  Minutes_Played  Total_Distance  High_Speed_Distance  \
# 0              1      100.405000     5688.225667            47.624667
# 1              4       90.186111    10594.647667           546.903667
# 2              6      100.051667    12214.495667           806.025000
# 3              7       98.961111    11450.744333           870.573667
# 4              8       20.385556     2296.656000           148.413667
# 5              9       89.423333    10663.393333           960.426333
# 6             10       98.532778    11040.271667           882.544333
# 7             13       20.216111     2598.009667           205.873333
# 8             14       78.052778     9279.789333           617.750333
# 9             15       99.679444    10953.370333           412.587000
# 10            17       26.531111     3272.511667           270.273333
# 11            18        8.218889      977.752333            30.294000
# 12            23       73.221667     8486.061333           767.790333
# 13            24       98.861111    11336.555667           709.004333
# 14            33       79.667222     9876.868333           569.051667
# 15            37        8.885556      935.122000            25.127667
#
#     Sprint_Distance  Sprint_Count
# 0         13.417667           2.0
# 1        158.955667           7.0
# 2        249.950000          10.0
# 3        305.448333          14.0
# 4         39.279333           2.0
# 5        175.681667          14.0
# 6        247.245000          12.0
# 7         66.295000           3.0
# 8        190.024000          10.0
# 9        114.228667           8.0
# 10       156.904667           3.0
# 11         3.157333           1.0
# 12       161.697667           8.0
# 13        78.232000           6.0
# 14       114.049000           5.0
# 15         0.000000           0.0

# %% [markdown]
# According to the organized team_0 & team_1 final table, by looking for the minutes_played for each player and
# compare with the commentary in the games on espn.com, I found the game for MW1 is the one ATX VS STL (2:3)

# %% [markdown]
# ## MW2

# %%
#classify and group by team
df_team2 = df2.groupby('TeamType')
#list each different team
# for name, team in df_team2:
#     print(f"Team {name}:")
#     print(team)
    
#fetch target team 0 and 1 from groupby object to dataframe object 
team_0 = df_team2.get_group(0)
team_1 = df_team2.get_group(1)
team_0.head(2)
# Out:
#       FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 4189     2127674         0            16      -2812      -2372         4.76
# 4190     2127675         0            16      -2822      -2377         4.70

# %% [markdown]
# ### MW2 Team 0

# %%
#calculate each framecount in minutes
team_0['Minutes_Played'] = 1/30/60

#Assume the instant speed is constant. Calculate the distance in each frame.
team_0['Total_Distance'] = team_0['PlayerSpeed']/30

#As a reference, according to the article 
#https://www.frontiersin.org/articles/10.3389/fspor.2023.1116293/full#:~:text=During%20official%20matches%2C%20high%2Dspeed,in%20professional%20male%20soccer%20players.
#high-speed distance ranges from 19.8km/h ~ 25.1km/h which is 5.5m/s ~ 7.0m/s
#and sprint distance ranges over 25.1km/h which is greater than 7.0m/s.

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_0['High_Speed_Distance'] = team_0.loc[(team_0['PlayerSpeed']>5.5) & (team_0['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_0['High_Speed_Distance'].fillna(0,inplace=True)

#Use distance = speed * time. Find PlayerSpeed greater than 7, then divide it by 30 to get distance
#per FrameCount
team_0['Sprint_Distance'] = team_0.loc[team_0['PlayerSpeed']>=7,'PlayerSpeed']/30
#Fill the None value in 'Sprint_Distance' with 0.
team_0['Sprint_Distance'].fillna(0,inplace=True)
# team_0

#The logic to find Sprint_Count is to divide FrameCount into groups with consecutive numbers. For each group,
#if there appears PlayerSpeed grater than 7, Sprint_Count += 1. 

# initializing list
tuple_list = []
#Set groups to divide FrameCount. If FrameCount.diff is greater than 1, set to another group.
team_0['Sprint_Count_Group'] = (team_0['FrameCount'].diff()>1).cumsum()
sprint_count_group = team_0.groupby(['Sprint_Count_Group','JerseyNumber'])
for name, group in sprint_count_group:
    #Search if any PlayerSpeed is greater than 7
    if (group['PlayerSpeed'] >=7).any():
        tuple_list.append(name)

result = defaultdict(list)
for sub in tuple_list:
    # getting all keys to values

    result[sub[1]].append(sub[0])
#put result into dict object
result = dict(result)
res_dict = dict()
for key in result:
    # getting unique key counts for each value
    res_dict[key] = len(list(set(result[key])))

res_df = pd.DataFrame(list(res_dict.items()),columns=['JerseyNumber','Sprint_Count'])

#Select columns from team_0
team0_result = team_0.groupby('JerseyNumber')[['Minutes_Played','Total_Distance','High_Speed_Distance','Sprint_Distance']].sum()
#Reset Indices to merge
team0_new = team0_result.reset_index()
#Merge two df
team0_final = team0_new.merge(res_df,how='left')
#fill Sprint_count = None with 0
team0_final = team0_final.fillna(0)
team0_final
# Out:
#     JerseyNumber  Minutes_Played  Total_Distance  High_Speed_Distance  \
# 0              6       97.365556     9753.253333           570.670667
# 1              7       96.793889    10017.254667           689.644333
# 2              8       86.940000    10122.524667           751.548333
# 3              9       97.585556     9395.940333           576.351000
# 4             11       71.946667     7818.280667           573.362667
# 5             13       97.068889    11176.201000           823.566000
# 6             14       98.000556    10351.465667           730.477000
# 7             16       72.125556     8168.039333           821.129667
# 8             17        8.596111      988.111000            98.338000
# 9             18       25.685556     2907.676333           176.584333
# 10            20       97.635556    10165.337333           687.972000
# 11            23       98.707778     5418.325667             7.611667
# 12            29       99.211667    10333.061667           593.706000
# 13            77       25.928333     3039.303000           225.638000
#
#     Sprint_Distance  Sprint_Count
# 0         92.131667           4.0
# 1        238.454667           7.0
# 2         46.704000           3.0
# 3        491.898667           8.0
# 4        236.812000           6.0
# 5        185.219333           9.0
# 6        300.530667          10.0
# 7         74.208667           4.0
# 8         48.556000           1.0
# 9         75.647000           4.0
# 10       107.241667           6.0
# 11         0.000000           0.0
# 12       166.789000           5.0
# 13        81.154667           1.0

# %% [markdown]
# ### MW2 Team 1

# %%
#calculate each framecount in minutes
team_1['Minutes_Played'] = 1/30/60

#Assume the instant speed is constant. Calculate the distance in each frame.
team_1['Total_Distance'] = team_1['PlayerSpeed']/30
#As a reference, according to the article 
#https://www.frontiersin.org/articles/10.3389/fspor.2023.1116293/full#:~:text=During%20official%20matches%2C%20high%2Dspeed,in%20professional%20male%20soccer%20players.
#high-speed distance ranges from 19.8km/h ~ 25.1km/h which is 5.5m/s ~ 7.0m/s
#and sprint distance ranges over 25.1km/h which is greater than 7.0m/s.

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_1['High_Speed_Distance'] = team_1.loc[(team_1['PlayerSpeed']>5.5) & (team_1['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_1['High_Speed_Distance'].fillna(0,inplace=True)

#Use distance = speed * time. Find PlayerSpeed greater than 7, then divide it by 30 to get distance
#per FrameCount
team_1['Sprint_Distance'] = team_1.loc[team_1['PlayerSpeed']>=7,'PlayerSpeed']/30
#Fill the None value in 'Sprint_Distance' with 0.
team_1['Sprint_Distance'].fillna(0,inplace=True)

#The logic to find Sprint_Count is to divide FrameCount into groups with consecutive numbers. For each group,
# initializing list
tuple_list = []
team_1['Sprint_Count_Group'] = (team_1['FrameCount'].diff()>1).cumsum()
sprint_count_group = team_1.groupby(['Sprint_Count_Group','JerseyNumber'])
for name, group in sprint_count_group:
    #if there appears PlayerSpeed grater than 7, Sprint_Count += 1. 
    if (group['PlayerSpeed'] >=7).any():
        tuple_list.append(name)

result = defaultdict(list)
for sub in tuple_list:
    # getting all keys to values

    result[sub[1]].append(sub[0])
    
#put result into a dict object
result = dict(result)
res_dict = dict()
for key in result:
    # getting unique key counts for each value
    res_dict[key] = len(list(set(result[key])))
    
#make dataframe res_df
res_df = pd.DataFrame(list(res_dict.items()),columns=['JerseyNumber','Sprint_Count'])
#Select columns from team_1
team1_result = team_1.groupby('JerseyNumber')[['Minutes_Played','Total_Distance','High_Speed_Distance','Sprint_Distance']].sum()
#Reset Indices to merge
team1_new = team1_result.reset_index()
#Merge two df
team1_final = team1_new.merge(res_df,how='left')
#fill Sprint_count = None with 0
team1_final = team1_final.fillna(0)
team1_final
# Out:
#     JerseyNumber  Minutes_Played  Total_Distance  High_Speed_Distance  \
# 0              1       98.277222     5794.829667            28.271667
# 1              2       96.542778    11017.347000           576.972333
# 2              6       97.380556    10473.122333           637.533667
# 3              7       76.391667     8993.013333           860.267333
# 4              8       70.427222     8306.048667          1006.609000
# 5              9       93.684444     9458.980667           440.257333
# 6             10       94.970000    10889.473333           625.183667
# 7             11       76.689444     8709.761667           528.519000
# 8             14       95.581111    10808.927333           760.420333
# 9             16       18.871111     2118.826333           185.411667
# 10            19       18.935556     2286.972333           184.766333
# 11            21       26.532222     3358.668333           376.214000
# 12            22       97.283889     9891.463333           392.075333
# 13            26       98.963333     9742.359000           515.571333
# 14            28        4.431111      606.401333            91.316000
#
#     Sprint_Distance  Sprint_Count
# 0          0.000000           0.0
# 1        286.444000          12.0
# 2        145.780667           5.0
# 3        128.653333           7.0
# 4        209.311333           7.0
# 5        217.232667           8.0
# 6        104.619000           7.0
# 7        252.411000           7.0
# 8        250.525333           9.0
# 9         72.027333           3.0
# 10        53.203000           2.0
# 11        94.585667           4.0
# 12        89.855000           6.0
# 13       185.390000           6.0
# 14        16.499667           1.0

# %% [markdown]
# According to the organized team_0 & team_1 final table, by looking for the minutes_played for each player and
# compare with the commentary in the games on espn.com, I found the game for MW2 is the one STL VS CLT (3:1)

# %% [markdown]
# ## MW5

# %%
#classify and group by team
df_team5 = df5.groupby('TeamType')
#list each different team
# for name, team in df_team5:
#     print(f"Team {name}:")
#     print(team)
    
#fetch target team 0 and 1 from groupby object to dataframe object 
team_0 = df_team5.get_group(0)
team_1 = df_team5.get_group(1)
team_0.head(2)
# Out:
#        FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 51146     2171713         0            10      -3709      -2663         5.30
# 51147     2171714         0            10      -3727      -2662         5.18

# %% [markdown]
# ### MW5 Team 0

# %%
#calculate each framecount in minutes
team_0['Minutes_Played'] = 1/30/60

#Assume the instant speed is constant. Calculate the distance in each frame.
team_0['Total_Distance'] = team_0['PlayerSpeed']/30

#As a reference, according to the article 
#https://www.frontiersin.org/articles/10.3389/fspor.2023.1116293/full#:~:text=During%20official%20matches%2C%20high%2Dspeed,in%20professional%20male%20soccer%20players.
#high-speed distance ranges from 19.8km/h ~ 25.1km/h which is 5.5m/s ~ 7.0m/s
#and sprint distance ranges over 25.1km/h which is greater than 7.0m/s.

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_0['High_Speed_Distance'] = team_0.loc[(team_0['PlayerSpeed']>5.5) & (team_0['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_0['High_Speed_Distance'].fillna(0,inplace=True)

#Use distance = speed * time. Find PlayerSpeed greater than 7, then divide it by 30 to get distance
#per FrameCount
team_0['Sprint_Distance'] = team_0.loc[team_0['PlayerSpeed']>=7,'PlayerSpeed']/30
#Fill the None value in 'Sprint_Distance' with 0.
team_0['Sprint_Distance'].fillna(0,inplace=True)
# team_0

#The logic to find Sprint_Count is to divide FrameCount into groups with consecutive numbers. For each group,
#if there appears PlayerSpeed grater than 7, Sprint_Count += 1. 

# initializing list
tuple_list = []
#Set groups to divide FrameCount. If FrameCount.diff is greater than 1, set to another group.
team_0['Sprint_Count_Group'] = (team_0['FrameCount'].diff()>1).cumsum()
sprint_count_group = team_0.groupby(['Sprint_Count_Group','JerseyNumber'])
for name, group in sprint_count_group:
    #Search if any PlayerSpeed is greater than 7
    if (group['PlayerSpeed'] >=7).any():
        tuple_list.append(name)

result = defaultdict(list)
for sub in tuple_list:
    # getting all keys to values

    result[sub[1]].append(sub[0])
#put result into dict object
result = dict(result)
res_dict = dict()
for key in result:
    # getting unique key counts for each value
    res_dict[key] = len(list(set(result[key])))

res_df = pd.DataFrame(list(res_dict.items()),columns=['JerseyNumber','Sprint_Count'])

#Select columns from team_0
team0_result = team_0.groupby('JerseyNumber')[['Minutes_Played','Total_Distance','High_Speed_Distance','Sprint_Distance']].sum()
#Reset Indices to merge
team0_new = team0_result.reset_index()
#Merge two df
team0_final = team0_new.merge(res_df,how='left')
#fill Sprint_count = None with 0
team0_final = team0_final.fillna(0)
team0_final
# Out:
#     JerseyNumber  Minutes_Played  Total_Distance  High_Speed_Distance  \
# 0              1       98.194444     5913.521667            24.482000
# 1              2       96.115556    11297.736333           685.873333
# 2              6       19.023333     2341.718667           129.135667
# 3              7       62.525000     7603.124333           592.138667
# 4              8       59.270000     7924.114667           821.931667
# 5              9       96.080556     9685.949333           492.854333
# 6             10       75.061111     9301.220000           545.181667
# 7             11       84.121667    10594.241333           678.347000
# 8             12       10.203889     1384.619000           130.721333
# 9             14       95.676111    10939.571667           709.481667
# 10            19       76.820556     8976.146667           712.070667
# 11            20       19.061111     2470.498000           118.192000
# 12            21       34.930000     4264.940667           397.032333
# 13            24       98.235000    11033.806000           735.223667
# 14            26       95.888889     9986.569000           513.823000
# 15            30       35.058333     4292.820667           298.895667
#
#     Sprint_Distance  Sprint_Count
# 0          0.000000           0.0
# 1        165.942000           8.0
# 2         55.218000           3.0
# 3         82.519667           5.0
# 4        158.313333          10.0
# 5        251.134667          12.0
# 6         91.140000           7.0
# 7        182.115333           9.0
# 8         55.551000           1.0
# 9        145.737000          11.0
# 10       236.528000           7.0
# 11         0.000000           0.0
# 12        43.782000           4.0
# 13       159.969333          11.0
# 14        79.587333           6.0
# 15        49.220667           4.0

# %% [markdown]
# ### MW5 Team 1

# %%
#calculate each framecount in minutes
team_1['Minutes_Played'] = 1/30/60

#Assume the instant speed is constant. Calculate the distance in each frame.
team_1['Total_Distance'] = team_1['PlayerSpeed']/30
#As a reference, according to the article 
#https://www.frontiersin.org/articles/10.3389/fspor.2023.1116293/full#:~:text=During%20official%20matches%2C%20high%2Dspeed,in%20professional%20male%20soccer%20players.
#high-speed distance ranges from 19.8km/h ~ 25.1km/h which is 5.5m/s ~ 7.0m/s
#and sprint distance ranges over 25.1km/h which is greater than 7.0m/s.

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_1['High_Speed_Distance'] = team_1.loc[(team_1['PlayerSpeed']>5.5) & (team_1['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_1['High_Speed_Distance'].fillna(0,inplace=True)

#Use distance = speed * time. Find PlayerSpeed greater than 7, then divide it by 30 to get distance
#per FrameCount
team_1['Sprint_Distance'] = team_1.loc[team_1['PlayerSpeed']>=7,'PlayerSpeed']/30
#Fill the None value in 'Sprint_Distance' with 0.
team_1['Sprint_Distance'].fillna(0,inplace=True)

#The logic to find Sprint_Count is to divide FrameCount into groups with consecutive numbers. For each group,
# initializing list
tuple_list = []
team_1['Sprint_Count_Group'] = (team_1['FrameCount'].diff()>1).cumsum()
sprint_count_group = team_1.groupby(['Sprint_Count_Group','JerseyNumber'])
for name, group in sprint_count_group:
    #if there appears PlayerSpeed grater than 7, Sprint_Count += 1. 
    if (group['PlayerSpeed'] >=7).any():
        tuple_list.append(name)

result = defaultdict(list)
for sub in tuple_list:
    # getting all keys to values

    result[sub[1]].append(sub[0])
    
#put result into a dict object
result = dict(result)
res_dict = dict()
for key in result:
    # getting unique key counts for each value
    res_dict[key] = len(list(set(result[key])))
    
#make dataframe res_df
res_df = pd.DataFrame(list(res_dict.items()),columns=['JerseyNumber','Sprint_Count'])
#Select columns from team_1
team1_result = team_1.groupby('JerseyNumber')[['Minutes_Played','Total_Distance','High_Speed_Distance','Sprint_Distance']].sum()
#Reset Indices to merge
team1_new = team1_result.reset_index()
#Merge two df
team1_final = team1_new.merge(res_df,how='left')
#fill Sprint_count = None with 0
team1_final = team1_final.fillna(0)
team1_final
# Out:
#     JerseyNumber  Minutes_Played  Total_Distance  High_Speed_Distance  \
# 0              2       96.682778    11172.946333           925.061000
# 1              4       96.417222     9549.583667           403.569333
# 2              7       95.983889    10648.238000           682.538000
# 3              8       72.042778     8629.820000           499.772000
# 4              9       60.722778     6947.482333           409.573000
# 5             10       35.546667     3397.905000           281.372667
# 6             11       72.752222     7567.569333           549.657000
# 7             15       98.274444    11008.800333           610.577333
# 8             16       23.313889     2621.902667           149.076667
# 9             17       23.850000     2765.672667           156.924333
# 10            18       98.079444     5030.696000            21.453333
# 11            23       24.012778     2980.239333           256.313667
# 12            25       95.890000    10183.114667           678.709000
# 13            28       96.313889    11721.289667           778.795333
# 14            29       72.741111     7768.775333           669.285667
#
#     Sprint_Distance  Sprint_Count
# 0        286.472667           7.0
# 1        107.928333           8.0
# 2        180.112667           6.0
# 3         64.239333           4.0
# 4        183.146000           8.0
# 5        129.572667           3.0
# 6        200.029333           6.0
# 7        175.877333          10.0
# 8          9.372000           1.0
# 9         23.310000           3.0
# 10         0.000000           0.0
# 11        23.258667           2.0
# 12        94.930000           9.0
# 13       135.211667           7.0
# 14       318.652000           5.0

# %% [markdown]
# According to the organized team_0 & team_1 final table, by looking for the minutes_played for each player and
# compare with the commentary in the games on espn.com, I found the game for MW5 is the one that RSL VS STL (0:4)

# %% [markdown]
# ## MW 7

# %%
#classify and group by team
df_team7 = df7.groupby('TeamType')
#list each different team
# for name, team in df_team7:
#     print(f"Team {name}:")
#     print(team)
    
#fetch target team 0 and 1 from groupby object to dataframe object 
team_0 = df_team7.get_group(0)
team_1 = df_team7.get_group(1)
team_0.head(2)
# Out:
#    FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 0     2121944         0            11         82        808         2.45
# 1     2121945         0            11         93        810         2.69

# %% [markdown]
# ### MW7 Team 0

# %%
#calculate each framecount in minutes
team_0['Minutes_Played'] = 1/30/60

#Assume the instant speed is constant. Calculate the distance in each frame.
team_0['Total_Distance'] = team_0['PlayerSpeed']/30

#As a reference, according to the article 
#https://www.frontiersin.org/articles/10.3389/fspor.2023.1116293/full#:~:text=During%20official%20matches%2C%20high%2Dspeed,in%20professional%20male%20soccer%20players.
#high-speed distance ranges from 19.8km/h ~ 25.1km/h which is 5.5m/s ~ 7.0m/s
#and sprint distance ranges over 25.1km/h which is greater than 7.0m/s.

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_0['High_Speed_Distance'] = team_0.loc[(team_0['PlayerSpeed']>5.5) & (team_0['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_0['High_Speed_Distance'].fillna(0,inplace=True)

#Use distance = speed * time. Find PlayerSpeed greater than 7, then divide it by 30 to get distance
#per FrameCount
team_0['Sprint_Distance'] = team_0.loc[team_0['PlayerSpeed']>=7,'PlayerSpeed']/30
#Fill the None value in 'Sprint_Distance' with 0.
team_0['Sprint_Distance'].fillna(0,inplace=True)
# team_0

#The logic to find Sprint_Count is to divide FrameCount into groups with consecutive numbers. For each group,
#if there appears PlayerSpeed grater than 7, Sprint_Count += 1. 

# initializing list
tuple_list = []
#Set groups to divide FrameCount. If FrameCount.diff is greater than 1, set to another group.
team_0['Sprint_Count_Group'] = (team_0['FrameCount'].diff()>1).cumsum()
sprint_count_group = team_0.groupby(['Sprint_Count_Group','JerseyNumber'])
for name, group in sprint_count_group:
    #Search if any PlayerSpeed is greater than 7
    if (group['PlayerSpeed'] >=7).any():
        tuple_list.append(name)

result = defaultdict(list)
for sub in tuple_list:
    # getting all keys to values

    result[sub[1]].append(sub[0])
#put result into dict object
result = dict(result)
res_dict = dict()
for key in result:
    # getting unique key counts for each value
    res_dict[key] = len(list(set(result[key])))

res_df = pd.DataFrame(list(res_dict.items()),columns=['JerseyNumber','Sprint_Count'])

#Select columns from team_0
team0_result = team_0.groupby('JerseyNumber')[['Minutes_Played','Total_Distance','High_Speed_Distance','Sprint_Distance']].sum()
#Reset Indices to merge
team0_new = team0_result.reset_index()
#Merge two df
team0_final = team0_new.merge(res_df,how='left')
#fill Sprint_count = None with 0
team0_final = team0_final.fillna(0)
team0_final
# Out:
#     JerseyNumber  Minutes_Played  Total_Distance  High_Speed_Distance  \
# 0              1       97.884444     5367.376333            41.023000
# 1              2       99.047222    11684.853333           894.095333
# 2              6       14.058889     1371.898000           120.307667
# 3              7       21.559444     2240.028667           161.055000
# 4              9       98.587778     9876.128000           598.562333
# 5             10       77.477778     9167.887000           464.845000
# 6             11       76.997222     9586.111333           749.459667
# 7             12       17.559444     2059.637000           283.408667
# 8             14       98.803889    11334.894667           889.107667
# 9             16       21.329444     2208.207000           171.364333
# 10            19       98.116667    10311.115667           632.081667
# 11            22       98.433333    10787.000000           653.683333
# 12            24       76.974444     9096.816333           638.649667
# 13            26       98.927778     9572.694000           414.669667
# 14            28       67.185556     8476.113000           505.734333
# 15            30       21.800000     2302.748333           202.316667
#
#     Sprint_Distance  Sprint_Count
# 0          0.000000           0.0
# 1        234.366667           5.0
# 2         13.752000           1.0
# 3         25.184000           1.0
# 4        264.795667           5.0
# 5         51.754000           2.0
# 6        172.472333           5.0
# 7         27.071333           2.0
# 8        205.992667           4.0
# 9         59.217000           2.0
# 10        85.471667           4.0
# 11       197.023667           4.0
# 12       185.732667           4.0
# 13       173.202333           6.0
# 14        86.440000           2.0
# 15        68.866667           3.0

# %% [markdown]
# ### MW7 Team 1

# %%
#calculate each framecount in minutes
team_1['Minutes_Played'] = 1/30/60

#Assume the instant speed is constant. Calculate the distance in each frame.
team_1['Total_Distance'] = team_1['PlayerSpeed']/30
#As a reference, according to the article 
#https://www.frontiersin.org/articles/10.3389/fspor.2023.1116293/full#:~:text=During%20official%20matches%2C%20high%2Dspeed,in%20professional%20male%20soccer%20players.
#high-speed distance ranges from 19.8km/h ~ 25.1km/h which is 5.5m/s ~ 7.0m/s
#and sprint distance ranges over 25.1km/h which is greater than 7.0m/s.

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_1['High_Speed_Distance'] = team_1.loc[(team_1['PlayerSpeed']>5.5) & (team_1['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_1['High_Speed_Distance'].fillna(0,inplace=True)

#Use distance = speed * time. Find PlayerSpeed greater than 7, then divide it by 30 to get distance
#per FrameCount
team_1['Sprint_Distance'] = team_1.loc[team_1['PlayerSpeed']>=7,'PlayerSpeed']/30
#Fill the None value in 'Sprint_Distance' with 0.
team_1['Sprint_Distance'].fillna(0,inplace=True)

#The logic to find Sprint_Count is to divide FrameCount into groups with consecutive numbers. For each group,
# initializing list
tuple_list = []
team_1['Sprint_Count_Group'] = (team_1['FrameCount'].diff()>1).cumsum()
sprint_count_group = team_1.groupby(['Sprint_Count_Group','JerseyNumber'])
for name, group in sprint_count_group:
    #if there appears PlayerSpeed grater than 7, Sprint_Count += 1. 
    if (group['PlayerSpeed'] >=7).any():
        tuple_list.append(name)

result = defaultdict(list)
for sub in tuple_list:
    # getting all keys to values

    result[sub[1]].append(sub[0])
    
#put result into a dict object
result = dict(result)
res_dict = dict()
for key in result:
    # getting unique key counts for each value
    res_dict[key] = len(list(set(result[key])))
    
#make dataframe res_df
res_df = pd.DataFrame(list(res_dict.items()),columns=['JerseyNumber','Sprint_Count'])
#Select columns from team_1
team1_result = team_1.groupby('JerseyNumber')[['Minutes_Played','Total_Distance','High_Speed_Distance','Sprint_Distance']].sum()
#Reset Indices to merge
team1_new = team1_result.reset_index()
#Merge two df
team1_final = team1_new.merge(res_df,how='left')
#fill Sprint_count = None with 0
team1_final = team1_final.fillna(0)
team1_final
# Out:
#     JerseyNumber  Minutes_Played  Total_Distance  High_Speed_Distance  \
# 0              5       97.338333     9696.331667           684.922667
# 1              7       97.649444    11476.436000           843.976000
# 2              9       34.800556     3581.249667           239.682667
# 3             10       98.873889    12777.755000          1052.207000
# 4             11       96.862222    11242.437000           564.194333
# 5             13       98.305000     9836.066333           788.601333
# 6             16       84.159444     9286.687000           536.621667
# 7             19       13.462222     1365.640000           110.702000
# 8             23       63.920000     6210.272333           407.118333
# 9             24       98.953889     5835.347333            10.622333
# 10            25       97.276111    10487.751333           347.363667
# 11            28       96.922778     9742.180333           425.640000
# 12            73        5.480000      759.989000            67.859333
# 13            84       92.246111    11332.396000           737.171667
#
#     Sprint_Distance  Sprint_Count
# 0        193.388333           4.0
# 1        243.550000           4.0
# 2         95.245000           1.0
# 3        172.501333           6.0
# 4        135.914333           5.0
# 5        314.686000           6.0
# 6        174.495333           7.0
# 7         34.237667           1.0
# 8        166.805333           3.0
# 9          0.000000           0.0
# 10       110.717000           2.0
# 11       110.570667           5.0
# 12        28.891333           1.0
# 13        78.539333           4.0

# %% [markdown]
# According to the organized team_0 & team_1 final table, by looking for the minutes_played for each player and
# compare with the commentary in the games on espn.com, I found the game for MW7 is the one that SEA VS STL (3:0)

# %% [markdown]
# ## MW8

# %%
#classify and group by team
df_team8 = df8.groupby('TeamType')
#list each different team
# for name, team in df_team8:
#     print(f"Team {name}:")
#     print(team)
    
#fetch target team 0 and 1 from groupby object to dataframe object 
team_0 = df_team8.get_group(0)
team_1 = df_team8.get_group(1)
team_0.head(2)
# Out:
#      FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 970     2356053         0            93      -2036       -926          0.0
# 971     2356054         0            93      -2031       -926          0.0

# %% [markdown]
# ### MW8 Team 0

# %%
#calculate each framecount in minutes
team_0['Minutes_Played'] = 1/30/60

#Assume the instant speed is constant. Calculate the distance in each frame.
team_0['Total_Distance'] = team_0['PlayerSpeed']/30

#As a reference, according to the article 
#https://www.frontiersin.org/articles/10.3389/fspor.2023.1116293/full#:~:text=During%20official%20matches%2C%20high%2Dspeed,in%20professional%20male%20soccer%20players.
#high-speed distance ranges from 19.8km/h ~ 25.1km/h which is 5.5m/s ~ 7.0m/s
#and sprint distance ranges over 25.1km/h which is greater than 7.0m/s.

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_0['High_Speed_Distance'] = team_0.loc[(team_0['PlayerSpeed']>5.5) & (team_0['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_0['High_Speed_Distance'].fillna(0,inplace=True)

#Use distance = speed * time. Find PlayerSpeed greater than 7, then divide it by 30 to get distance
#per FrameCount
team_0['Sprint_Distance'] = team_0.loc[team_0['PlayerSpeed']>=7,'PlayerSpeed']/30
#Fill the None value in 'Sprint_Distance' with 0.
team_0['Sprint_Distance'].fillna(0,inplace=True)
# team_0

#The logic to find Sprint_Count is to divide FrameCount into groups with consecutive numbers. For each group,
#if there appears PlayerSpeed grater than 7, Sprint_Count += 1. 

# initializing list
tuple_list = []
#Set groups to divide FrameCount. If FrameCount.diff is greater than 1, set to another group.
team_0['Sprint_Count_Group'] = (team_0['FrameCount'].diff()>1).cumsum()
sprint_count_group = team_0.groupby(['Sprint_Count_Group','JerseyNumber'])
for name, group in sprint_count_group:
    #Search if any PlayerSpeed is greater than 7
    if (group['PlayerSpeed'] >=7).any():
        tuple_list.append(name)

result = defaultdict(list)
for sub in tuple_list:
    # getting all keys to values

    result[sub[1]].append(sub[0])
#put result into dict object
result = dict(result)
res_dict = dict()
for key in result:
    # getting unique key counts for each value
    res_dict[key] = len(list(set(result[key])))

res_df = pd.DataFrame(list(res_dict.items()),columns=['JerseyNumber','Sprint_Count'])

#Select columns from team_0
team0_result = team_0.groupby('JerseyNumber')[['Minutes_Played','Total_Distance','High_Speed_Distance','Sprint_Distance']].sum()
#Reset Indices to merge
team0_new = team0_result.reset_index()
#Merge two df
team0_final = team0_new.merge(res_df,how='left')
#fill Sprint_count = None with 0
team0_final = team0_final.fillna(0)
team0_final
# Out:
#     JerseyNumber  Minutes_Played  Total_Distance  High_Speed_Distance  \
# 0              2       15.578889     1907.894333           157.377667
# 1              4       49.355556     4868.926333           239.426667
# 2              5       61.728333     6164.902000           342.110000
# 3              8       47.401111     5390.149333           478.925667
# 4             13       89.578889     9125.632333           631.326667
# 5             14       46.703889     5052.740667           117.912000
# 6             15       95.269444     9387.520667           685.281667
# 7             17       80.366667     7656.862667           602.692000
# 8             18       96.381111     5413.104333             0.000000
# 9             19       95.946667     9814.305000           586.757000
# 10            21       96.072222     9544.433667           464.000333
# 11            26       33.904444     4082.532000           251.073333
# 12            28        5.836111      728.537667           118.816333
# 13            29       49.470556     4702.147000           270.025000
# 14            31       95.180556     9967.090667           771.567000
# 15            93       93.184444     9267.387333           436.911333
#
#     Sprint_Distance  Sprint_Count
# 0        142.197333           1.0
# 1         91.178333           4.0
# 2        116.765667           2.0
# 3        122.710333           2.0
# 4        246.320667           6.0
# 5         93.345667           1.0
# 6        314.126667          10.0
# 7        287.698667           8.0
# 8          0.000000           0.0
# 9        189.792000           8.0
# 10       171.022667           8.0
# 11        36.347000           2.0
# 12        58.067333           1.0
# 13       102.462667           6.0
# 14       224.788333           7.0
# 15       105.996333           4.0

# %% [markdown]
# ### MW8 Team 1

# %%
#calculate each framecount in minutes
team_1['Minutes_Played'] = 1/30/60

#Assume the instant speed is constant. Calculate the distance in each frame.
team_1['Total_Distance'] = team_1['PlayerSpeed']/30
#As a reference, according to the article 
#https://www.frontiersin.org/articles/10.3389/fspor.2023.1116293/full#:~:text=During%20official%20matches%2C%20high%2Dspeed,in%20professional%20male%20soccer%20players.
#high-speed distance ranges from 19.8km/h ~ 25.1km/h which is 5.5m/s ~ 7.0m/s
#and sprint distance ranges over 25.1km/h which is greater than 7.0m/s.

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_1['High_Speed_Distance'] = team_1.loc[(team_1['PlayerSpeed']>5.5) & (team_1['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_1['High_Speed_Distance'].fillna(0,inplace=True)

#Use distance = speed * time. Find PlayerSpeed greater than 7, then divide it by 30 to get distance
#per FrameCount
team_1['Sprint_Distance'] = team_1.loc[team_1['PlayerSpeed']>=7,'PlayerSpeed']/30
#Fill the None value in 'Sprint_Distance' with 0.
team_1['Sprint_Distance'].fillna(0,inplace=True)

#The logic to find Sprint_Count is to divide FrameCount into groups with consecutive numbers. For each group,
# initializing list
tuple_list = []
team_1['Sprint_Count_Group'] = (team_1['FrameCount'].diff()>1).cumsum()
sprint_count_group = team_1.groupby(['Sprint_Count_Group','JerseyNumber'])
for name, group in sprint_count_group:
    #if there appears PlayerSpeed grater than 7, Sprint_Count += 1. 
    if (group['PlayerSpeed'] >=7).any():
        tuple_list.append(name)

result = defaultdict(list)
for sub in tuple_list:
    # getting all keys to values

    result[sub[1]].append(sub[0])
    
#put result into a dict object
result = dict(result)
res_dict = dict()
for key in result:
    # getting unique key counts for each value
    res_dict[key] = len(list(set(result[key])))
    
#make dataframe res_df
res_df = pd.DataFrame(list(res_dict.items()),columns=['JerseyNumber','Sprint_Count'])
#Select columns from team_1
team1_result = team_1.groupby('JerseyNumber')[['Minutes_Played','Total_Distance','High_Speed_Distance','Sprint_Distance']].sum()
#Reset Indices to merge
team1_new = team1_result.reset_index()
#Merge two df
team1_final = team1_new.merge(res_df,how='left')
#fill Sprint_count = None with 0
team1_final = team1_final.fillna(0)
team1_final
# Out:
#     JerseyNumber  Minutes_Played  Total_Distance  High_Speed_Distance  \
# 0              1       97.260000     4918.212333            16.882667
# 1              2       97.200556    10868.654667           724.521333
# 2              7       17.983889     2242.826667           182.651333
# 3              8       81.823889     9887.049333           928.451000
# 4              9       94.387778     9184.322000           640.784333
# 5             10       94.972222    11409.073333           749.016333
# 6             11       75.760556     9236.156333           637.512000
# 7             12       10.511111     1427.865333           134.556000
# 8             14       63.815556     6979.230333           590.667333
# 9             17       31.540556     3825.701333           369.180667
# 10            19       76.981111     8468.232000           529.231667
# 11            20       18.155556     2404.291000           116.647667
# 12            21       63.443889     7264.797333           577.417667
# 13            22       96.198333    10288.959667           481.109000
# 14            26       95.498333     9530.531000           447.869667
# 15            30       31.870000     3832.201333           321.360000
#
#     Sprint_Distance  Sprint_Count
# 0          0.000000           0.0
# 1        207.143667          11.0
# 2        103.886667           2.0
# 3        237.201333          10.0
# 4        436.894000          14.0
# 5         71.569333           5.0
# 6        235.689000          11.0
# 7        130.908667           2.0
# 8        214.549333           9.0
# 9        130.969333           2.0
# 10       158.039000           7.0
# 11        14.978000           1.0
# 12       267.203000           9.0
# 13       211.186667           7.0
# 14       101.575333           4.0
# 15       163.095667           3.0

# %% [markdown]
# According to the organized team_0 & team_1 final table, by looking for the minutes_played for each player and
# compare with the commentary in the games on espn.com, I found the game for MW8 is the one STL VS CIN (5:1)

# %% [markdown]
# ## Pressing Strategy Analysis

# %%
def find_game_frame_count(df, goal_keeper_jersey_0,goal_keeper_jersey_1):
    df_team0 = df.loc[(df['TeamType']== 0)]
    df_team0_goalkeeper = df_team0.loc[df_team0['JerseyNumber']==goal_keeper_jersey_0]
    temp1 = df_team0_goalkeeper.loc[df_team0_goalkeeper['XPosition']>0].sort_values(by='FrameCount')
    temp2 = df_team0_goalkeeper.loc[df_team0_goalkeeper['XPosition']<0].sort_values(by='FrameCount')
    if temp1['FrameCount'].max() < temp2['FrameCount'].min():
        first_half_0 = df_team0.loc[(df_team0['FrameCount']>=temp1['FrameCount'].min()) & (df_team0['FrameCount']<=temp1['FrameCount'].max())]
        second_half_0 = df_team0.loc[(df_team0['FrameCount']>=temp2['FrameCount'].min()) & (df_team0['FrameCount']<=temp2['FrameCount'].max())]
        first_half_0_attack = first_half_0.loc[first_half_0['XPosition']<0]
        second_half_0_attack = second_half_0.loc[second_half_0['XPosition']>0]

    else:
        second_half_0 = df_team0.loc[(df_team0['FrameCount']>=temp1['FrameCount'].min()) & (df_team0['FrameCount']<=temp1['FrameCount'].max())]
        first_half_0 = df_team0.loc[(df_team0['FrameCount']>=temp2['FrameCount'].min()) & (df_team0['FrameCount']<=temp2['FrameCount'].max())]
        first_half_0_attack = first_half_0.loc[first_half_0['XPosition']>0]
        second_half_0_attack = second_half_0.loc[second_half_0['XPosition']<0]
        
    df_team1 = df.loc[(df['TeamType']== 1)]
    df_team1_goalkeeper = df_team1.loc[df_team1['JerseyNumber']==goal_keeper_jersey_1]
    temp1 = df_team1_goalkeeper.loc[df_team1_goalkeeper['XPosition']>0].sort_values(by='FrameCount')
    temp2 = df_team1_goalkeeper.loc[df_team1_goalkeeper['XPosition']<0].sort_values(by='FrameCount')
    if temp1['FrameCount'].max() < temp2['FrameCount'].min():
        first_half_1 = df_team1.loc[(df_team1['FrameCount']>=temp1['FrameCount'].min()) & (df_team1['FrameCount']<=temp1['FrameCount'].max())]
        second_half_1 = df_team1.loc[(df_team1['FrameCount']>=temp2['FrameCount'].min()) & (df_team1['FrameCount']<=temp2['FrameCount'].max())]
        first_half_1_attack = first_half_1.loc[first_half_1['XPosition']<0]
        second_half_1_attack = second_half_1.loc[second_half_1['XPosition']>0]

    else:
        second_half_1 = df_team1.loc[(df_team1['FrameCount']>=temp1['FrameCount'].min()) & (df_team1['FrameCount']<=temp1['FrameCount'].max())]
        first_half_1 = df_team1.loc[(df_team1['FrameCount']>=temp2['FrameCount'].min()) & (df_team1['FrameCount']<=temp2['FrameCount'].max())]
        first_half_1_attack = first_half_1.loc[first_half_1['XPosition']>0]
        second_half_1_attack = second_half_1.loc[second_half_1['XPosition']<0]
    return first_half_0_attack, second_half_0_attack, first_half_1_attack, second_half_1_attack

# %% [markdown]
# ### MW1

# %%
import matplotlib.pyplot as plt

# %%
#STL is 0. ATX is 1.
#initialize the variables to plug into the function
df,goal_keeper_jersey_0,goal_keeper_jersey_1 = df1,1,1
#Call find_game_frame_count to return the four dataframes
first_half_0_attack, second_half_0_attack, first_half_1_attack, second_half_1_attack = find_game_frame_count(df,goal_keeper_jersey_0,goal_keeper_jersey_1)

# %%
#Initialize the list for listing the counts of attackers on the opponents' field with a high speed
attack_high_speed_list = []

# %%
# Find the length of data of players on the opponents’ field at a high speed. Compare the data for both teams. Compare the data for STL in all 5 matches.
#Initialize empty high_speed list for MW1.
MW1_high_speed = []
#find the length of the total high speed time for both teams
high_speed_0 = len(first_half_0_attack.loc[first_half_0_attack['PlayerSpeed']>=5.5])+len(second_half_0_attack.loc[second_half_0_attack['PlayerSpeed']>=5.5])
#append to the list
MW1_high_speed.append(high_speed_0)
high_speed_1 = len(first_half_1_attack.loc[first_half_1_attack['PlayerSpeed']>=5.5])+len(second_half_1_attack.loc[second_half_1_attack['PlayerSpeed']>=5.5])
MW1_high_speed.append(high_speed_1)
#append to total attack_high_speed_list
attack_high_speed_list.append(MW1_high_speed)

# %%
#Initialize the list for listing the time of attackers on the opponents' field
attack_time_percentage_list = []

# %%
#Find the percentage of time that players spent on the opponents’ field VS total time. 
# Compare the data for both teams. Compare the data for STL in all 5 matches.
#Initialize empty time_percentage list for MW1.
MW1_time_percentage = []
time_percentage_0 = (len(first_half_0_attack)+len(second_half_0_attack))/len(df)
#append to the list
MW1_time_percentage.append(time_percentage_0)
time_percentage_1 = (len(first_half_1_attack)+len(second_half_1_attack))/len(df)
MW1_time_percentage.append(time_percentage_1)
#append to total attack_time_percentage_list
attack_time_percentage_list.append(MW1_time_percentage)

# %% [markdown]
# ### MW2

# %%
#STL is 1. CLT is 0.
#initialize the variables to plug into the function
df,goal_keeper_jersey_0,goal_keeper_jersey_1 = df2,23,1
#Call find_game_frame_count to return the four dataframes
first_half_0_attack, second_half_0_attack, first_half_1_attack, second_half_1_attack = find_game_frame_count(df,goal_keeper_jersey_0,goal_keeper_jersey_1)

# Find the length of data of players on the opponents’ field at a high speed. Compare the data for both teams. Compare the data for STL in all 5 matches.
#Initialize empty high_speed list for MW1.
MW2_high_speed = []
#find the length of the total high speed time for both teams
high_speed_0 = len(first_half_0_attack.loc[first_half_0_attack['PlayerSpeed']>=5.5])+len(second_half_0_attack.loc[second_half_0_attack['PlayerSpeed']>=5.5])
#append to the list
MW2_high_speed.append(high_speed_0)
high_speed_1 = len(first_half_1_attack.loc[first_half_1_attack['PlayerSpeed']>=5.5])+len(second_half_1_attack.loc[second_half_1_attack['PlayerSpeed']>=5.5])
MW2_high_speed.append(high_speed_1)
#append to total attack_high_speed_list
attack_high_speed_list.append(MW2_high_speed)

#Find the percentage of time that players spent on the opponents’ field VS total time. 
# Compare the data for both teams. Compare the data for STL in all 5 matches.
#Initialize empty time_percentage list for MW1.
MW2_time_percentage = []
time_percentage_0 = (len(first_half_0_attack)+len(second_half_0_attack))/len(df)
#append to the list
MW2_time_percentage.append(time_percentage_0)
time_percentage_1 = (len(first_half_1_attack)+len(second_half_1_attack))/len(df)
MW2_time_percentage.append(time_percentage_1)
#append to total attack_time_percentage_list
attack_time_percentage_list.append(MW2_time_percentage)

# %% [markdown]
# ### MW5

# %%
#STL is 0. RSL is 1.
#initialize the variables to plug into the function
df,goal_keeper_jersey_0,goal_keeper_jersey_1 = df5,1,18
#Call find_game_frame_count to return the four dataframes
first_half_0_attack, second_half_0_attack, first_half_1_attack, second_half_1_attack = find_game_frame_count(df,goal_keeper_jersey_0,goal_keeper_jersey_1)

# Find the length of data of players on the opponents’ field at a high speed. Compare the data for both teams. Compare the data for STL in all 5 matches.
#Initialize empty high_speed list for MW1.
MW5_high_speed = []
#find the length of the total high speed time for both teams
high_speed_0 = len(first_half_0_attack.loc[first_half_0_attack['PlayerSpeed']>=5.5])+len(second_half_0_attack.loc[second_half_0_attack['PlayerSpeed']>=5.5])
#append to the list
MW5_high_speed.append(high_speed_0)
high_speed_1 = len(first_half_1_attack.loc[first_half_1_attack['PlayerSpeed']>=5.5])+len(second_half_1_attack.loc[second_half_1_attack['PlayerSpeed']>=5.5])
MW5_high_speed.append(high_speed_1)
#append to total attack_high_speed_list
attack_high_speed_list.append(MW5_high_speed)

#Find the percentage of time that players spent on the opponents’ field VS total time. 
# Compare the data for both teams. Compare the data for STL in all 5 matches.
#Initialize empty time_percentage list for MW1.
MW5_time_percentage = []
time_percentage_0 = (len(first_half_0_attack)+len(second_half_0_attack))/len(df)
#append to the list
MW5_time_percentage.append(time_percentage_0)
time_percentage_1 = (len(first_half_1_attack)+len(second_half_1_attack))/len(df)
MW5_time_percentage.append(time_percentage_1)
#append to total attack_time_percentage_list
attack_time_percentage_list.append(MW5_time_percentage)

# %% [markdown]
# ### MW7

# %%
#STL is 0. SEA is 1.
#initialize the variables to plug into the function
df,goal_keeper_jersey_0,goal_keeper_jersey_1 = df7,1,24
#Call find_game_frame_count to return the four dataframes
first_half_0_attack, second_half_0_attack, first_half_1_attack, second_half_1_attack = find_game_frame_count(df,goal_keeper_jersey_0,goal_keeper_jersey_1)

# Find the length of data of players on the opponents’ field at a high speed. Compare the data for both teams. Compare the data for STL in all 5 matches.
#Initialize empty high_speed list for MW1.
MW7_high_speed = []
#find the length of the total high speed time for both teams
high_speed_0 = len(first_half_0_attack.loc[first_half_0_attack['PlayerSpeed']>=5.5])+len(second_half_0_attack.loc[second_half_0_attack['PlayerSpeed']>=5.5])
#append to the list
MW7_high_speed.append(high_speed_0)
high_speed_1 = len(first_half_1_attack.loc[first_half_1_attack['PlayerSpeed']>=5.5])+len(second_half_1_attack.loc[second_half_1_attack['PlayerSpeed']>=5.5])
MW7_high_speed.append(high_speed_1)
#append to total attack_high_speed_list
attack_high_speed_list.append(MW7_high_speed)

#Find the percentage of time that players spent on the opponents’ field VS total time. 
# Compare the data for both teams. Compare the data for STL in all 5 matches.
#Initialize empty time_percentage list for MW1.
MW7_time_percentage = []
time_percentage_0 = (len(first_half_0_attack)+len(second_half_0_attack))/len(df)
#append to the list
MW7_time_percentage.append(time_percentage_0)
time_percentage_1 = (len(first_half_1_attack)+len(second_half_1_attack))/len(df)
MW7_time_percentage.append(time_percentage_1)
#append to total attack_time_percentage_list
attack_time_percentage_list.append(MW7_time_percentage)

# %% [markdown]
# ### MW8

# %%
#STL is 1. CIN is 0.
#initialize the variables to plug into the function
df,goal_keeper_jersey_0,goal_keeper_jersey_1 = df8,18,1
#Call find_game_frame_count to return the four dataframes
first_half_0_attack, second_half_0_attack, first_half_1_attack, second_half_1_attack = find_game_frame_count(df,goal_keeper_jersey_0,goal_keeper_jersey_1)

# Find the length of data of players on the opponents’ field at a high speed. Compare the data for both teams. Compare the data for STL in all 5 matches.
#Initialize empty high_speed list for MW1.
MW8_high_speed = []
#find the length of the total high speed time for both teams
high_speed_0 = len(first_half_0_attack.loc[first_half_0_attack['PlayerSpeed']>=5.5])+len(second_half_0_attack.loc[second_half_0_attack['PlayerSpeed']>=5.5])
#append to the list
MW8_high_speed.append(high_speed_0)
high_speed_1 = len(first_half_1_attack.loc[first_half_1_attack['PlayerSpeed']>=5.5])+len(second_half_1_attack.loc[second_half_1_attack['PlayerSpeed']>=5.5])
MW8_high_speed.append(high_speed_1)
#append to total attack_high_speed_list
attack_high_speed_list.append(MW8_high_speed)

#Find the percentage of time that players spent on the opponents’ field VS total time. 
# Compare the data for both teams. Compare the data for STL in all 5 matches.
#Initialize empty time_percentage list for MW1.
MW8_time_percentage = []
time_percentage_0 = (len(first_half_0_attack)+len(second_half_0_attack))/len(df)
#append to the list
MW8_time_percentage.append(time_percentage_0)
time_percentage_1 = (len(first_half_1_attack)+len(second_half_1_attack))/len(df)
MW8_time_percentage.append(time_percentage_1)
#append to total attack_time_percentage_list
attack_time_percentage_list.append(MW8_time_percentage)

# %%
attack_high_speed_list
# Out:
# [[32270, 26328],
#  [22243, 32106],
#  [24620, 22053],
#  [20938, 27123],
#  [21236, 22149]]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the data and labels from the given list

data = [32270, 26328,22243, 32106, 24620, 22053,20938, 27123,21236, 22149]

labels = ['MW1_STL','MW1_ATX','MW2_CLT', 'MW2_STL', 'MW5_STL','MW5_RSL', 'MW7_STL','MW7_SEA', 'MW8_CIN','MW8_STL']
colors = ['red','green','blue','red','red','brown','red',"#006400","#00008B",'red']
plt.figure(figsize=(12,6))
# Plot a histogram of each sub-list
plt.bar(labels, data,color=colors)

# Add labels for the x and y axes
# plt.xlabel('Data')
plt.ylabel('Attack_High_Speed_Count')

for i in range(len(data) - 1):
    if i % 2 == 1:
        plt.axvline(x=i+0.5, color='gray', linestyle='--')

# Show the plot
plt.show()

# %%
attack_time_percentage_list
# Out:
# [[0.21069968620077745, 0.1366672476227922],
#  [0.1343794984774875, 0.2205880124593195],
#  [0.1443508572085751, 0.1520686095449853],
#  [0.12484595886565844, 0.20513141554531072],
#  [0.14651432548827162, 0.11546502082803878]]

# %%
import numpy as np

# Define the data and labels from the given list

data = [0.21069968620077745, 0.1366672476227922,
        0.1343794984774875, 0.2205880124593195,
        0.1443508572085751, 0.1520686095449853,
        0.12484595886565844, 0.20513141554531072,
        0.14651432548827162, 0.11546502082803878]

labels = ['MW1_STL','MW1_ATX','MW2_CLT', 'MW2_STL', 'MW5_STL','MW5_RSL', 'MW7_STL','MW7_SEA', 'MW8_CIN','MW8_STL']
colors = ['red','green','blue','red','red','brown','red',"#006400","#00008B",'red']
plt.figure(figsize=(12,6))
# Plot a histogram of each sub-list
plt.bar(labels, data,color=colors)

# Add labels for the x and y axes
# plt.xlabel('Data')
plt.ylabel('Attack_Time_Percentage')

for i in range(len(data) - 1):
    if i % 2 == 1:
        plt.axvline(x=i+0.5, color='gray', linestyle='--')

# Show the plot
plt.show()

# %% [markdown]
# ### MW1 individual analysis

# %%
#classify and group by team
df1_team = df1.groupby('TeamType')
#fetch target team 0 and 1 from groupby object to dataframe object 
team_0 = df1_team.get_group(0)
team_1 = df1_team.get_group(1)

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_0['High_Speed_Distance'] = team_0.loc[(team_0['PlayerSpeed']>5.5) & (team_0['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_0['High_Speed_Distance'].fillna(0,inplace=True)
#make a column to count high_speed_appearance for team_0
team_0['High_Speed_Appearance'] = 0
team_0['High_Speed_Appearance'] = team_0.loc[team_0['High_Speed_Distance']!=0,'High_Speed_Appearance']+1
team_0['High_Speed_Appearance'].fillna(0,inplace=True)

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_1['High_Speed_Distance'] = team_1.loc[(team_1['PlayerSpeed']>5.5) & (team_1['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_1['High_Speed_Distance'].fillna(0,inplace=True)
#Same for team_1
team_1['High_Speed_Appearance'] = 0
team_1['High_Speed_Appearance'] = team_1.loc[team_1['High_Speed_Distance']!=0,'High_Speed_Appearance']+1
team_1['High_Speed_Appearance'].fillna(0,inplace=True)

#Aim to plot the total high speed time for each player

#find all data with Sprint_Appearance = 1
df_counts = team_0[team_0['High_Speed_Appearance']>0]
#Find high_speed_appearance for each player
counts = df_counts.groupby('JerseyNumber')['High_Speed_Appearance'].count()
counts.plot(kind='bar')
plt.ylabel('Team0 High Speed Appearance Count')
plt.show()

# %%
#Aim to plot the total high speed time for each player

#find all data with Sprint_Appearance = 1
df_counts = team_1[team_1['High_Speed_Appearance']>0]
#Find high_speed_appearance for each player
counts = df_counts.groupby('JerseyNumber')['High_Speed_Appearance'].count()
counts.plot(kind='bar')
plt.ylabel('Team1 High Speed Appearance Count')
plt.show()

# %% [markdown]
# ### MW2 individual analysis

# %%
#classify and group by team
df2_team = df2.groupby('TeamType')
#fetch target team 0 and 1 from groupby object to dataframe object 
team_0 = df2_team.get_group(0)
team_1 = df2_team.get_group(1)

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_0['High_Speed_Distance'] = team_0.loc[(team_0['PlayerSpeed']>5.5) & (team_0['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_0['High_Speed_Distance'].fillna(0,inplace=True)
#make a column to count high_speed_appearance for team_0
team_0['High_Speed_Appearance'] = 0
team_0['High_Speed_Appearance'] = team_0.loc[team_0['High_Speed_Distance']!=0,'High_Speed_Appearance']+1
team_0['High_Speed_Appearance'].fillna(0,inplace=True)

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_1['High_Speed_Distance'] = team_1.loc[(team_1['PlayerSpeed']>5.5) & (team_1['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_1['High_Speed_Distance'].fillna(0,inplace=True)
#Same for team_1
team_1['High_Speed_Appearance'] = 0
team_1['High_Speed_Appearance'] = team_1.loc[team_1['High_Speed_Distance']!=0,'High_Speed_Appearance']+1
team_1['High_Speed_Appearance'].fillna(0,inplace=True)

#Aim to plot the total high speed time for each player

#find all data with Sprint_Appearance = 1
df_counts = team_0[team_0['High_Speed_Appearance']>0]
#Find high_speed_appearance for each player
counts = df_counts.groupby('JerseyNumber')['High_Speed_Appearance'].count()
counts.plot(kind='bar')
plt.ylabel('Team0 High Speed Appearance Count')
plt.show()

# %%
#Aim to plot the total high speed time for each player

#find all data with Sprint_Appearance = 1
df_counts = team_1[team_1['High_Speed_Appearance']>0]
#Find high_speed_appearance for each player
counts = df_counts.groupby('JerseyNumber')['High_Speed_Appearance'].count()
counts.plot(kind='bar')
plt.ylabel('Team1 High Speed Appearance Count')
plt.show()

# %% [markdown]
# ### MW5 individual analysis

# %%
#classify and group by team
df5_team = df5.groupby('TeamType')
#fetch target team 0 and 1 from groupby object to dataframe object 
team_0 = df5_team.get_group(0)
team_1 = df5_team.get_group(1)

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_0['High_Speed_Distance'] = team_0.loc[(team_0['PlayerSpeed']>5.5) & (team_0['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_0['High_Speed_Distance'].fillna(0,inplace=True)
#make a column to count high_speed_appearance for team_0
team_0['High_Speed_Appearance'] = 0
team_0['High_Speed_Appearance'] = team_0.loc[team_0['High_Speed_Distance']!=0,'High_Speed_Appearance']+1
team_0['High_Speed_Appearance'].fillna(0,inplace=True)

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_1['High_Speed_Distance'] = team_1.loc[(team_1['PlayerSpeed']>5.5) & (team_1['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_1['High_Speed_Distance'].fillna(0,inplace=True)
#Same for team_1
team_1['High_Speed_Appearance'] = 0
team_1['High_Speed_Appearance'] = team_1.loc[team_1['High_Speed_Distance']!=0,'High_Speed_Appearance']+1
team_1['High_Speed_Appearance'].fillna(0,inplace=True)

#Aim to plot the total high speed time for each player

#find all data with Sprint_Appearance = 1
df_counts = team_0[team_0['High_Speed_Appearance']>0]
#Find high_speed_appearance for each player
counts = df_counts.groupby('JerseyNumber')['High_Speed_Appearance'].count()
counts.plot(kind='bar')
plt.ylabel('Team0 High Speed Appearance Count')
plt.show()

# %%
#Aim to plot the total high speed time for each player

#find all data with Sprint_Appearance = 1
df_counts = team_1[team_1['High_Speed_Appearance']>0]
#Find high_speed_appearance for each player
counts = df_counts.groupby('JerseyNumber')['High_Speed_Appearance'].count()
counts.plot(kind='bar')
plt.ylabel('Team1 High Speed Appearance Count')
plt.show()

# %% [markdown]
# ### MW7 individual analysis

# %%
#classify and group by team
df7_team = df7.groupby('TeamType')
#fetch target team 0 and 1 from groupby object to dataframe object 
team_0 = df7_team.get_group(0)
team_1 = df7_team.get_group(1)

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_0['High_Speed_Distance'] = team_0.loc[(team_0['PlayerSpeed']>5.5) & (team_0['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_0['High_Speed_Distance'].fillna(0,inplace=True)
#make a column to count high_speed_appearance for team_0
team_0['High_Speed_Appearance'] = 0
team_0['High_Speed_Appearance'] = team_0.loc[team_0['High_Speed_Distance']!=0,'High_Speed_Appearance']+1
team_0['High_Speed_Appearance'].fillna(0,inplace=True)

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_1['High_Speed_Distance'] = team_1.loc[(team_1['PlayerSpeed']>5.5) & (team_1['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_1['High_Speed_Distance'].fillna(0,inplace=True)
#Same for team_1
team_1['High_Speed_Appearance'] = 0
team_1['High_Speed_Appearance'] = team_1.loc[team_1['High_Speed_Distance']!=0,'High_Speed_Appearance']+1
team_1['High_Speed_Appearance'].fillna(0,inplace=True)

#Aim to plot the total high speed time for each player

#find all data with Sprint_Appearance = 1
df_counts = team_0[team_0['High_Speed_Appearance']>0]
#Find high_speed_appearance for each player
counts = df_counts.groupby('JerseyNumber')['High_Speed_Appearance'].count()
counts.plot(kind='bar')
plt.ylabel('Team0 High Speed Appearance Count')
plt.show()

# %%
#Aim to plot the total high speed time for each player

#find all data with Sprint_Appearance = 1
df_counts = team_1[team_1['High_Speed_Appearance']>0]
#Find high_speed_appearance for each player
counts = df_counts.groupby('JerseyNumber')['High_Speed_Appearance'].count()
counts.plot(kind='bar')
plt.ylabel('Team1 High Speed Appearance Count')
plt.show()

# %% [markdown]
# ### MW8 individual analysis

# %%
#classify and group by team
df8_team = df8.groupby('TeamType')
#fetch target team 0 and 1 from groupby object to dataframe object 
team_0 = df8_team.get_group(0)
team_1 = df8_team.get_group(1)

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_0['High_Speed_Distance'] = team_0.loc[(team_0['PlayerSpeed']>5.5) & (team_0['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_0['High_Speed_Distance'].fillna(0,inplace=True)
#make a column to count high_speed_appearance for team_0
team_0['High_Speed_Appearance'] = 0
team_0['High_Speed_Appearance'] = team_0.loc[team_0['High_Speed_Distance']!=0,'High_Speed_Appearance']+1
team_0['High_Speed_Appearance'].fillna(0,inplace=True)

#Use distance = speed * time. Find PlayerSpeed within the range of 5.5 and 7, then divide it by 30 to get distance
#per FrameCount
team_1['High_Speed_Distance'] = team_1.loc[(team_1['PlayerSpeed']>5.5) & (team_1['PlayerSpeed']<7),'PlayerSpeed']/30
#Fill the None value in 'High_Speed_Distance' with 0.
team_1['High_Speed_Distance'].fillna(0,inplace=True)
#Same for team_1
team_1['High_Speed_Appearance'] = 0
team_1['High_Speed_Appearance'] = team_1.loc[team_1['High_Speed_Distance']!=0,'High_Speed_Appearance']+1
team_1['High_Speed_Appearance'].fillna(0,inplace=True)

#Aim to plot the total high speed time for each player

#find all data with Sprint_Appearance = 1
df_counts = team_0[team_0['High_Speed_Appearance']>0]
#Find high_speed_appearance for each player
counts = df_counts.groupby('JerseyNumber')['High_Speed_Appearance'].count()
counts.plot(kind='bar')
plt.ylabel('Team0 High Speed Appearance Count')
plt.show()

# %%
#Aim to plot the total high speed time for each player

#find all data with Sprint_Appearance = 1
df_counts = team_1[team_1['High_Speed_Appearance']>0]
#Find high_speed_appearance for each player
counts = df_counts.groupby('JerseyNumber')['High_Speed_Appearance'].count()
counts.plot(kind='bar')
plt.ylabel('Team1 High Speed Appearance Count')
plt.show()

# %% [markdown]
# # Note: The following are drafts and are some potentially useful analysis saved for later.

# %%
df8_play = df8.loc[(df8['TeamType']== 0) | (df8['TeamType']==1)]
df8_play
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 970         2356053         0            93      -2036       -926         0.00
# 971         2356054         0            93      -2031       -926         0.00
# 972         2356055         0            93      -2026       -928         0.00
# 973         2356056         0            93      -2021       -928         0.00
# 974         2356057         0            93      -2017       -929         0.00
# ...             ...       ...           ...        ...        ...          ...
# 5746044     2485953         1            11       1766      -3466         0.00
# 5746045     2485954         1            11       1766      -3466         0.04
# 5746046     2485955         1            11       1766      -3466         0.04
# 5746047     2485956         1            11       1766      -3467         0.04
# 5746048     2485957         1            11       1767      -3467         0.00
#
# [3778852 rows x 6 columns]

# %%
df8_play.groupby(['FrameCount','TeamType']).count()
# Out:
#                      JerseyNumber  XPosition  YPosition  PlayerSpeed
# FrameCount TeamType
# 2355083    0                    5          5          5            5
#            1                    9          9          9            9
# 2355084    0                    5          5          5            5
#            1                    9          9          9            9
# 2355085    0                    5          5          5            5
# ...                           ...        ...        ...          ...
# 2555624    1                   11         11         11           11
# 2555625    0                   11         11         11           11
#            1                   11         11         11           11
# 2555626    0                   11         11         11           11
#            1                   11         11         11           11
#
# [352907 rows x 4 columns]

# %%
agg = df8_play.groupby(['FrameCount','TeamType'])

# %%
t = 0
for time, data in agg:
    print(time)
    print(data)
    if t > 5:
        break
    t += 1
# Out:
# (2355083, 0)
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 200542      2355083         0            29        259       1219         1.58
# 601626      2355083         0            15      -2078       1124         0.72
# 1604336     2355083         0            21      -2373        -66         0.28
# 2607046     2355083         0             4      -2122      -1210         0.78
# 4211382     2355083         0            18      -4659          0         0.66
# (2355083, 1)
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 401084      2355083         1            19        803        592         1.10
# 1403794     2355083         1             9       -599         25         4.00
# 1804878     2355083         1            14       1096      -2347         1.08
# 2005420     2355083         1             2       1000       1623         3.41
# 2807588     2355083         1            22       1695      -1189         0.70
# 3008130     2355083         1             1       3994         26         1.02
# 3208672     2355083         1            21       -597      -1822         4.06
# 3409214     2355083         1            10        190       -835         2.34
# 4010840     2355083         1            26       2159        158         0.10
# (2355084, 0)
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 200543      2355084         0            29        259       1217         1.41
# 601627      2355084         0            15      -2078       1120         0.73
# 1604337     2355084         0            21      -2373        -64         0.32
# 2607047     2355084         0             4      -2121      -1209         0.78
# 4211383     2355084         0            18      -4655         -1         0.72
# (2355084, 1)
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 401085      2355084         1            19        799        594         1.06
# 1403795     2355084         1             9       -612         23         3.95
# 1804879     2355084         1            14       1091      -2343         1.10
# 2005421     2355084         1             2        989       1619         3.43
# 2807589     2355084         1            22       1692      -1187         0.72
# 3008131     2355084         1             1       3990         26         1.02
# 3208673     2355084         1            21       -608      -1815         4.06
# 3409215     2355084         1            10        182       -836         2.37
# 4010841     2355084         1            26       2158        158         0.06
# (2355085, 0)
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 200544      2355085         0            29        259       1214         1.10
# 601628      2355085         0            15      -2078       1116         0.77
# 1604338     2355085         0            21      -2373        -62         0.35
# 2607048     2355085         0             4      -2120      -1209         0.74
# 4211384     2355085         0            18      -4653         -2         0.77
# (2355085, 1)
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 401086      2355085         1            19        796        596         1.07
# 1403796     2355085         1             9       -624         21         3.91
# 1804880     2355085         1            14       1086      -2340         1.13
# 2005422     2355085         1             2        978       1616         3.43
# 2807590     2355085         1            22       1689      -1185         0.72
# 3008132     2355085         1             1       3988         27         0.97
# 3208674     2355085         1            21       -620      -1809         4.06
# 3409216     2355085         1            10        173       -836         2.39
# 4010842     2355085         1            26       2156        160         0.09
# (2355086, 0)
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 200545      2355086         0            29        258       1212         0.81
# 601629      2355086         0            15      -2078       1112         0.78
# 1604339     2355086         0            21      -2372        -60         0.42
# 2607049     2355086         0             4      -2120      -1209         0.76
# 4211385     2355086         0            18      -4650         -4         0.81

# %%
# p=0
# create a new empty dataframe to store the results
result_df = pd.DataFrame()
radius = 1000
for group,data in agg:
    if group[1] == 0:
        df_0 = data
        continue
    if group[1] == 1:
        df_1 = data
#     if p < 5: 
#         p +=1
    else:
        break
        # loop over each row in df_0
    for i, row in df_0.iterrows():
        # get the center coordinates from df_0
        center_x, center_y = row['XPosition'], row['YPosition']
        upper_x, lower_x, upper_y, lower_y = row['XPosition'] + radius,row['XPosition'] - radius,row['YPosition'] + radius,row['YPosition'] - radius

        df_result = df_1.loc[(df_1['XPosition'] > lower_x)&(df_1['XPosition'] < upper_x)&(df_1['YPosition'] > lower_y)&(df_1['YPosition'] < upper_y)]
        df_result['opponent_center_name'] = row['JerseyNumber']

        result_df = pd.concat([result_df, df_result])

    # reset the index of the result dataframe
result_df = result_df.reset_index(drop=True)

# print the result dataframe
result_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/y9/tpf4g1_15nqbl3j7qy_tnvzm0000gn/T/ipykernel_43758/2006422634.py in <module>
#      22         df_result['opponent_center_name'] = row['JerseyNumber']
#      23
# ---> 24         result_df = pd.concat([result_df, df_result])
#      25
#      26 #             # check if any points in df_1 are within a radius of 1000 units from the center point
#
# KeyboardInterrupt:

# %%
# p=0
# create a new empty dataframe to store the results
result_df = pd.DataFrame()
radius = 1000
for group,data in agg:
    if group[1] == 0:
        df_0 = data
        continue
    if group[1] == 1:
        df_1 = data
#     if p < 5: 
#         p +=1
    else:
        break
        # loop over each row in df_0
    for i, row in df_0.iterrows():
        # get the center coordinates from df_0
        center_x, center_y = row['XPosition'], row['YPosition']

            # check if any points in df_1 are within a radius of 1000 units from the center point
            mask = df_1.apply(lambda x: is_within_range(center_x, center_y, x['XPosition'], x['YPosition'], radius=10000), axis=1)

            # create a new dataframe with the rows from df_1 that are within the radius
            within_radius_df = df_1[mask]

            # add a new column to the within_radius_df dataframe with the distance from the center point
            within_radius_df['distance'] = within_radius_df.apply(lambda x: np.sqrt((x['XPosition'] - center_x) ** 2 + (x['YPosition'] - center_y) ** 2), axis=1)

            # add a new column to the within_radius_df dataframe with the name of the center point
            within_radius_df['opponent_center_name'] = row['JerseyNumber']

            # add the within_radius_df dataframe to the result dataframe
            result_df = pd.concat([result_df, within_radius_df])

    # reset the index of the result dataframe
result_df = result_df.reset_index(drop=True)

# print the result dataframe
result_df

# %%
# !pip install geohash
# Out:
# Collecting geohash
#   Downloading Geohash-1.0.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: docutils>=0.3 in /Users/yuyaozhuge/opt/anaconda3/lib/python3.9/site-packages (from geohash) (0.18.1)
# Building wheels for collected packages: geohash
#   Building wheel for geohash (setup.py) ... done
#   Created wheel for geohash: filename=Geohash-1.0-py3-none-any.whl size=15524 sha256=2fec4bb4a1a680128bf35b0cc5af79aa8d4a39471c7f009b38f0307df8d4c10f
#   Stored in directory: /Users/yuyaozhuge/Library/Caches/pip/wheels/06/13/b0/b79bd8e426feed6f8c7c23eda5b8a7891751549701eea312ae
# Successfully built geohash
# Installing collected packages: geohash
# Successfully installed geohash-1.0

# %%
df_0
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 200544      2355085         0            29        259       1214         1.10
# 601628      2355085         0            15      -2078       1116         0.77
# 1604338     2355085         0            21      -2373        -62         0.35
# 2607048     2355085         0             4      -2120      -1209         0.74
# 4211384     2355085         0            18      -4653         -2         0.77

# %%
for i, row in df_0.iterrows():
    print(row)
# Out:
# FrameCount      2355085.0
# TeamType              0.0
# JerseyNumber         29.0
# XPosition           259.0
# YPosition          1214.0
# PlayerSpeed           1.1
# Name: 200544, dtype: float64
# FrameCount      2355085.00
# TeamType              0.00
# JerseyNumber         15.00
# XPosition         -2078.00
# YPosition          1116.00
# PlayerSpeed           0.77
# Name: 601628, dtype: float64
# FrameCount      2355085.00
# TeamType              0.00
# JerseyNumber         21.00
# XPosition         -2373.00
# YPosition           -62.00
# PlayerSpeed           0.35
# Name: 1604338, dtype: float64
# FrameCount      2355085.00
# TeamType              0.00
# JerseyNumber          4.00
# XPosition         -2120.00
# YPosition         -1209.00
# PlayerSpeed           0.74
# Name: 2607048, dtype: float64
# FrameCount      2355085.00
# TeamType              0.00
# JerseyNumber         18.00
# XPosition         -4653.00
# YPosition            -2.00
# PlayerSpeed           0.77
# Name: 4211384, dtype: float64

# %%
# p = 0
# create a new empty dataframe to store the results
result_df = pd.DataFrame()
for group,data in agg:
#     print(i)
#     print(i[0])
#     print(j)
#     print(j['XPosition'])
#     if p < 6: 
#         p +=1
#     else:
#         break
    if group[1] == 0:
        df_0 = data
    if group[1] == 1:
        df_1 = data

        # loop over each row in df_0
        for i, row in df_0.iterrows():
            # get the center coordinates from df_0
            center_x, center_y = row['XPosition'], row['YPosition']

            # check if any points in df_1 are within a radius of 1000 units from the center point
            mask = df_1.apply(lambda x: is_within_range(center_x, center_y, x['XPosition'], x['YPosition'], radius=10000), axis=1)

            # create a new dataframe with the rows from df_1 that are within the radius
            within_radius_df = df_1[mask]

            # add a new column to the within_radius_df dataframe with the distance from the center point
            within_radius_df['distance'] = within_radius_df.apply(lambda x: np.sqrt((x['XPosition'] - center_x) ** 2 + (x['YPosition'] - center_y) ** 2), axis=1)

            # add a new column to the within_radius_df dataframe with the name of the center point
            within_radius_df['opponent_center_name'] = row['JerseyNumber']

            # add the within_radius_df dataframe to the result dataframe
            result_df = pd.concat([result_df, within_radius_df])

        # reset the index of the result dataframe
        result_df = result_df.reset_index(drop=True)

# print the result dataframe
result_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/y9/tpf4g1_15nqbl3j7qy_tnvzm0000gn/T/ipykernel_43758/3777028031.py in <module>
#      34
#      35             # add the within_radius_df dataframe to the result dataframe
# ---> 36             result_df = pd.concat([result_df, within_radius_df])
#      37
#      38         # reset the index of the result dataframe
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     358     )
#     359
# --> 360     return op.get_result()
#     361
#     362
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     593                 mgrs_indexers.append((obj._mgr, indexers))
#     594
# --> 595             new_data = concatenate_managers(
#     596                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     597             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/concat.py in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     230                 #  we can use np.concatenate, which is more performant
#     231                 #  than concat_compat
# --> 232                 values = np.concatenate(vals, axis=1)
#     233             else:
#     234                 # TODO(EA2D): special-casing not needed with 2D EAs
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
def is_within_range(center_x, center_y, x, y, radius=600):
    """
    Check if a given point (x, y) is within a given radius from a center point (center_x, center_y)
    """
    distance = np.sqrt((x - center_x) ** 2 + (y - center_y) ** 2)
    return distance <= radius

# %%
df_example = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie', 'David'],
    'XPosition': [0, 10, 20, 30],
    'YPosition': [0, 10, 20, 30]
})
df_example
# Out:
#       name  XPosition  YPosition
# 0    Alice          0          0
# 1      Bob         10         10
# 2  Charlie         20         20
# 3    David         30         30

# %%
for i in df_example.loc[:,'name']:
    print(i)
# Out:
# Alice
# Bob
# Charlie
# David

# %%
df_time8 = team_0.groupby('FrameCount').count()
plt.plot(range(len(df_time8['TeamType'])),df_time8['TeamType'])

# %%
df_time8 = team_1.groupby('FrameCount').count()
plt.plot(range(len(df_time8['TeamType'])),df_time8['TeamType'])

# %%
team_0
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 970         2356053         0            93      -2036       -926         0.00
# 971         2356054         0            93      -2031       -926         0.00
# 972         2356055         0            93      -2026       -928         0.00
# 973         2356056         0            93      -2021       -928         0.00
# 974         2356057         0            93      -2017       -929         0.00
# ...             ...       ...           ...        ...        ...          ...
# 5564085     2504536         0            21       5408       2569         4.98
# 5564086     2504537         0            21       5417       2572         4.67
# 5564087     2504538         0            21       5425       2576         4.31
# 5564088     2504539         0            21       5430       2578         3.87
# 5564089     2504540         0            21       5435       2577         3.53
#
# [1893526 rows x 6 columns]

# %%
jersey = team_0.groupby('JerseyNumber')
result_dict = {}
i = 0
for number, data in jersey:
    if i <3:
        result_dict[number] = data.head(2).to_dict(orient='records')
        i += 1
    else:
        break
print(result_dict)
# Out:
# {2: [{'FrameCount': 2553963, 'TeamType': 0, 'JerseyNumber': 2, 'XPosition': 1030, 'YPosition': 3363, 'PlayerSpeed': 0.0}, {'FrameCount': 2553964, 'TeamType': 0, 'JerseyNumber': 2, 'XPosition': 1027, 'YPosition': 3358, 'PlayerSpeed': 0.0}], 4: [{'FrameCount': 2355083, 'TeamType': 0, 'JerseyNumber': 4, 'XPosition': -2122, 'YPosition': -1210, 'PlayerSpeed': 0.78}, {'FrameCount': 2355084, 'TeamType': 0, 'JerseyNumber': 4, 'XPosition': -2121, 'YPosition': -1209, 'PlayerSpeed': 0.78}], 5: [{'FrameCount': 2370482, 'TeamType': 0, 'JerseyNumber': 5, 'XPosition': -26, 'YPosition': -3442, 'PlayerSpeed': 1.63}, {'FrameCount': 2370483, 'TeamType': 0, 'JerseyNumber': 5, 'XPosition': -24, 'YPosition': -3441, 'PlayerSpeed': 1.58}]}

# %%
jersey = team_1.groupby('JerseyNumber')
result_dict = {}
i = 0
for number, data in jersey:
    if i <3:
        result_dict[number] = data.head(2).to_dict(orient='records')
        i += 1
    else:
        break
print(result_dict)
# Out:
# {1: [{'FrameCount': 2375216, 'TeamType': 1, 'JerseyNumber': 1, 'XPosition': 4885, 'YPosition': -638, 'PlayerSpeed': 0.59}, {'FrameCount': 2375217, 'TeamType': 1, 'JerseyNumber': 1, 'XPosition': 4878, 'YPosition': -651, 'PlayerSpeed': 0.56}], 2: [{'FrameCount': 2372767, 'TeamType': 1, 'JerseyNumber': 2, 'XPosition': -703, 'YPosition': 1880, 'PlayerSpeed': 1.04}, {'FrameCount': 2372768, 'TeamType': 1, 'JerseyNumber': 2, 'XPosition': -698, 'YPosition': 1881, 'PlayerSpeed': 1.04}], 7: [{'FrameCount': 2533452, 'TeamType': 1, 'JerseyNumber': 7, 'XPosition': 1301, 'YPosition': -4, 'PlayerSpeed': 0.04}, {'FrameCount': 2533453, 'TeamType': 1, 'JerseyNumber': 7, 'XPosition': 1298, 'YPosition': -4, 'PlayerSpeed': 0.12}]}

# %%
dict_8 = dict([(i,[x,y,z]) for i,x,y,z in zip(team_0['FrameCount'], team_0['JerseyNumber'],team_0['Duration'],team_0['Discount'])])

# %%
team_type = 1
team_data = df8[df8['TeamType'] == team_type]
team_data
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 17682       2372767         1             2       -703       1880         1.04
# 17683       2372768         1             2       -698       1881         1.04
# 17684       2372769         1             2       -694       1881         1.09
# 17685       2372770         1             2       -690       1882         1.09
# 17686       2372771         1             2       -686       1884         1.13
# ...             ...       ...           ...        ...        ...          ...
# 5746044     2485953         1            11       1766      -3466         0.00
# 5746045     2485954         1            11       1766      -3466         0.04
# 5746046     2485955         1            11       1766      -3466         0.04
# 5746047     2485956         1            11       1766      -3467         0.04
# 5746048     2485957         1            11       1767      -3467         0.00
#
# [1885326 rows x 6 columns]

# %%
opponent_team = 1 - team_type
team_data0 = df8[df8['TeamType'] == opponent_team]
team_data0
# Out:
#          FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 970         2356053         0            93      -2036       -926         0.00
# 971         2356054         0            93      -2031       -926         0.00
# 972         2356055         0            93      -2026       -928         0.00
# 973         2356056         0            93      -2021       -928         0.00
# 974         2356057         0            93      -2017       -929         0.00
# ...             ...       ...           ...        ...        ...          ...
# 5564085     2504536         0            21       5408       2569         4.98
# 5564086     2504537         0            21       5417       2572         4.67
# 5564087     2504538         0            21       5425       2576         4.31
# 5564088     2504539         0            21       5430       2578         3.87
# 5564089     2504540         0            21       5435       2577         3.53
#
# [1893526 rows x 6 columns]

# %%
team_data = team_data.head(100)
team_data
# Out:
#        FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 17682     2372767         1             2       -703       1880         1.04
# 17683     2372768         1             2       -698       1881         1.04
# 17684     2372769         1             2       -694       1881         1.09
# 17685     2372770         1             2       -690       1882         1.09
# 17686     2372771         1             2       -686       1884         1.13
# ...           ...       ...           ...        ...        ...          ...
# 17777     2372862         1             2       -320       1866         1.05
# 17778     2372863         1             2       -315       1865         1.09
# 17779     2372864         1             2       -312       1864         1.05
# 17780     2372865         1             2       -307       1863         1.10
# 17781     2372866         1             2       -304       1862         1.09
#
# [100 rows x 6 columns]

# %%
df8_100 = df8.head(100)
df8_100
# Out:
#     FrameCount  TeamType  JerseyNumber  XPosition  YPosition  PlayerSpeed
# 0      2355083        -1            -1      -1039        299          0.0
# 1      2355084        -1            -1      -1042        301          0.0
# 2      2355085        -1            -1      -1045        302          0.0
# 3      2355086        -1            -1      -1048        304          0.0
# 4      2355087        -1            -1      -1050        305          0.0
# ..         ...       ...           ...        ...        ...          ...
# 95     2355178        -1            -1      -1546        -59          0.0
# 96     2355179        -1            -1      -1555        -64          0.0
# 97     2355180        -1            -1      -1564        -70          0.0
# 98     2355181        -1            -1      -1574        -76          0.0
# 99     2355182        -1            -1      -1584        -81          0.0
#
# [100 rows x 6 columns]

# %%
team_data['Distance'] = np.sqrt((team_data['XPosition'] - df8_100[df8_100['TeamType'] == opponent_team]['XPosition'].values)**2 + (team_data['YPosition'] - df8_100[df8_100['TeamType'] == opponent_team]['YPosition'].values)**2)
team_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/y9/tpf4g1_15nqbl3j7qy_tnvzm0000gn/T/ipykernel_43758/1979787718.py in <module>
# ----> 1 team_data['Distance'] = np.sqrt((team_data['XPosition'] - df8_100[df8_100['TeamType'] == opponent_team]['XPosition'].values)**2 + (team_data['YPosition'] - df8_100[df8_100['TeamType'] == opponent_team]['YPosition'].values)**2)
#       2 team_data
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in __sub__(self, other)
#     106     @unpack_zerodim_and_defer("__sub__")
#     107     def __sub__(self, other):
# --> 108         return self._arith_method(other, operator.sub)
#     109
#     110     @unpack_zerodim_and_defer("__rsub__")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _arith_method(self, other, op)
#    5637     def _arith_method(self, other, op):
#    5638         self, other = ops.align_method_SERIES(self, other)
# -> 5639         return base.IndexOpsMixin._arith_method(self, other, op)
#    5640
#    5641
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/base.py in _arith_method(self, other, op)
#    1293
#    1294         with np.errstate(all="ignore"):
# -> 1295             result = ops.arithmetic_op(lvalues, rvalues, op)
#    1296
#    1297         return self._construct_result(result, name=res_name)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     220         _bool_arith_check(op, left, right)
#     221
# --> 222         res_values = _na_arithmetic_op(left, right, op)
#     223
#     224     return res_values
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     161
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#     165         if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     237         if use_numexpr:
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#     241
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     126
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#     130     return result
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     if _TEST_MODE:
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#      71
#
# ValueError: operands could not be broadcast together with shapes (100,) (0,)

# %%
for time,
